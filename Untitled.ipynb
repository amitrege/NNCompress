# %% [markdown]
# # Install Importance Sampling module for Keras

# %%
# Install Dependency
# !pip3 install blinker

# Clone Repo
# !pip install --user keras-importance-sampling
# !git clone https://github.com/idiap/importance-sampling.git
  
# Convert the repo into a module for usage in the notebook
# !touch importance-sampling/__init__.py
# !touch importance-sampling/importance_sampling/__init__.py
# !touch importance-sampling/examples/__init__.py
# !cp -r importance-sampling/* .

# Copy contents of repo for easy usage 
# !cp -r importance-sampling/* .
# Out:
# Collecting blinker
#   Downloading https://files.pythonhosted.org/packages/1b/51/e2a9f3b757eb802f61dc1f2b09c8c99f6eb01cf06416c0671253536517b6/blinker-1.4.tar.gz (111kB)
#      |████████████████████████████████| 112kB 2.8MB/s
# Building wheels for collected packages: blinker
#   Building wheel for blinker (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/92/a0/00/8690a57883956a301d91cf4ec999cc0b258b01e3f548f86e89
# Successfully built blinker
# Installing collected packages: blinker
# Successfully installed blinker-1.4
# Collecting keras-importance-sampling
#   Downloading https://files.pythonhosted.org/packages/b2/ac/f79031d912e993f7d43500ef964ea43eb83795ffcf23a36b66e5057676b8/keras-importance-sampling-0.8.tar.gz (40kB)
#      |████████████████████████████████| 40kB 3.1MB/s
# Requirement already satisfied: keras>=2 in /usr/local/lib/python3.6/dist-packages (from keras-importance-sampling) (2.2.4)
# Requirement already satisfied: blinker in /usr/local/lib/python3.6/dist-packages (from keras-importance-sampling) (1.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from keras-importance-sampling) (1.16.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras>=2->keras-importance-sampling) (3.13)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras>=2->keras-importance-sampling) (1.0.9)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from keras>=2->keras-importance-sampling) (1.0.7)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras>=2->keras-importance-sampling) (1.2.1)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras>=2->keras-importance-sampling) (1.12.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras>=2->keras-importance-sampling) (2.8.0)
# Building wheels for collected packages: keras-importance-sampling
#   Building wheel for keras-importance-sampling (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/04/0c/09/53a134f3839e74f2d11d755f06452734e919d049c6737b0c36
# Successfully built keras-importance-sampling
# Installing collected packages: keras-importance-sampling
# Successfully installed keras-importance-sampling-0.8
# Cloning into 'importance-sampling'...
# remote: Enumerating objects: 799, done.
# remote: Total 799 (delta 0), reused 0 (delta 0), pack-reused 799
# Receiving objects: 100% (799/799), 1.00 MiB | 13.32 MiB/s, done.
# Resolving deltas: 100% (551/551), done.

# %% [markdown]
# # Imports

# %%
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Activation
import numpy as np

import time

from keras import backend as K
from keras.callbacks import LearningRateScheduler, Callback
from keras.datasets import cifar10
from keras.layers import Activation, BatchNormalization, Conv2D, Dense, \
    GlobalAveragePooling2D, Input, add
from keras.models import Model
from keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras.utils import to_categorical
from keras.models import load_model

from importance_sampling.datasets import CIFAR10, ZCAWhitening
from importance_sampling.models import wide_resnet
from importance_sampling.training import ImportanceTraining
from examples.example_utils import get_parser
from importance_sampling.layers.normalization import LayerNormalization

import matplotlib.pyplot as plt

from IPython.display import Image, display
from google.colab import files

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# # Wide Resnet Baseline on CIFAR 10

# %% [markdown]
# ## Helper Classes

# %%
class TrainingSchedule(Callback):
    """Implement the training schedule for training a resnet on CIFAR10 for a
    given time budget."""
    def __init__(self, total_time):
        self._total_time = total_time
        self._lr = self._get_lr(0.0)

    def _get_lr(self, progress):
        if progress > 0.8:
            return 0.004
        elif progress > 0.5:
            return 0.02
        else:
            return 0.1

    def on_train_begin(self, logs={}):
        self._start = time.time()
        self._lr = self._get_lr(0.0)
        K.set_value(self.model.optimizer.lr, self._lr)

    def on_batch_end(self, batch, logs):
        t = time.time() - self._start

        if t >= self._total_time:
            self.model.stop_training = True

        lr = self._get_lr(t / self._total_time)
        if lr != self._lr:
            self._lr = lr
            K.set_value(self.model.optimizer.lr, self._lr)

    @property
    def lr(self):
        return self._lr

class Args():
  def __init__(self, depth, width, presample, batch_size, time_budget, dropout, useIS):
    self.depth = depth
    self.width = width
    self.presample = presample
    self.batch_size = batch_size
    self.time_budget = 3600*time_budget
    self.dropout = dropout
    self.importance_training = useIS

# %% [markdown]
# ## Load Dataset

# %%
# Load Dataset
dset = ZCAWhitening(CIFAR10())
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 51s 0us/step

# %% [markdown]
# ## Model Utility Functions

# %% [markdown]
# ### Build Model

# %%
def build_model(args, dset):
  training_schedule = TrainingSchedule(args.time_budget)
  model = wide_resnet(args.depth, args.width, args.dropout)(dset.shape, dset.output_size)
  model.compile(
      loss="categorical_crossentropy",
      optimizer=SGD(lr=training_schedule.lr, momentum=0.9),
      metrics=["accuracy"]
  )
  model.summary()
  return model, training_schedule

# %% [markdown]
# ### Train Model

# %%
def train_model(model, args, x_train, y_train, x_test, y_test, training_schedule):
  # Create the data augmentation generator
  datagen = ImageDataGenerator(
      # set input mean to 0 over the dataset
      featurewise_center=False,
      # set each sample mean to 0
      samplewise_center=False,
      # divide inputs by std of dataset
      featurewise_std_normalization=False,
      # divide each input by its std
      samplewise_std_normalization=False,
      # apply ZCA whitening
      zca_whitening=False,
      # randomly rotate images in the range (deg 0 to 180)
      rotation_range=0,
      # randomly shift images horizontally
      width_shift_range=0.1,
      # randomly shift images vertically
      height_shift_range=0.1,
      # randomly flip images
      horizontal_flip=True,
      # randomly flip images
      vertical_flip=False)
  datagen.fit(x_train)

  # Train the model
  if args.importance_training:
      history = ImportanceTraining(model).fit_generator(
          datagen.flow(x_train, y_train, batch_size=args.batch_size),
          validation_data=(x_test, y_test),
          epochs=10**6,
          verbose=1,
          callbacks=[training_schedule],
          batch_size=args.batch_size,
          steps_per_epoch=int(np.ceil(float(len(x_train)) / args.batch_size))
      )
  else:
      history = model.fit_generator(
          datagen.flow(x_train, y_train, batch_size=args.batch_size),
          validation_data=(x_test, y_test),
          epochs=10**6,
          verbose=1,
          callbacks=[training_schedule],
          steps_per_epoch=int(np.ceil(float(len(x_train)) / args.batch_size))
      )
  return model, history

# %% [markdown]
# ### Evaluate Model

# %%
# Score trained model.
def eval_model(model, x_test, y_test):
  scores = model.evaluate(x_test, y_test, verbose=1)
  print('Test loss:', scores[0])
  print('Test accuracy:', scores[1])

# %% [markdown]
# ### Wrapper

# %%
def build_wide_res(args, dset):
  # Split dataset
  x_train, y_train = dset.train_data[:]
  x_test, y_test = dset.test_data[:]

  model, training_schedule = build_model(args, dset)
  model, history = train_model(model, args, x_train, y_train, x_test, y_test, training_schedule)
  return model, history

# %% [markdown]
# ### Saving the model and plots to Drive

# %%
def save_model(model, file_name):
  path = "gdrive/My Drive/"
  model.save(path + file_name + '.h5')
  
def save_plots(model, history, file_name, useIS):
  path = "gdrive/My Drive/" + file_name
  
  # Hack for a minor annoyance
  if useIS:
    acc = history.history['accuracy'][:-1]
    val_acc = history.history['val_accuracy'][:-1]
  else:
    acc = history.history['acc'][:-1]
    val_acc = history.history['val_acc'][:-1]
    
  # summarize history for accuracy
  plt.plot(acc)
  plt.plot(val_acc)
  plt.title('model accuracy')
  plt.ylabel('accuracy')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')
  plt.savefig(path + "-acc.png")
  plt.show()

  # summarize history for loss
  plt.plot(history.history['loss'][:-1])
  plt.plot(history.history['val_loss'][:-1])
  plt.title('model loss')
  plt.ylabel('loss')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')
  plt.savefig(path + "-loss.png")
  plt.show()
  
def save_history(history, file_name, useIS):
  path = "gdrive/My Drive/" + file_name + "-history"
  
  if useIS:
    acc_hist = np.array(history.history['accuracy'][:-1])
    val_acc_hist = np.array(history.history['val_accuracy'][:-1])
  else:
    acc_hist = np.array(history.history['acc'][:-1])
    val_acc_hist = np.array(history.history['val_acc'][:-1])
    
  loss_hist = np.array(history.history['loss'][:-1])
  val_loss_hist = np.array(history.history['val_loss'][:-1])
  
  np.save(path, np.vstack((acc_hist, val_acc_hist, loss_hist, val_loss_hist)))
  
  
def save(model, history, file_name, useIS):
  save_model(model, file_name)
  save_plots(model, history, file_name, useIS)
  save_history(history, file_name, useIS)

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### Wide ResNet 28-2 with 0.3 dropout and max time of 1 hr (with IS)

# %%
args = Args(depth = 28, width = 2, presample = 3.0, batch_size = 128, time_budget = 1, dropout = 0.3, useIS = True)
model, history = build_wide_res(args, dset)
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_7 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_113 (Conv2D)             (None, 32, 32, 16)   432         input_7[0][0]
# __________________________________________________________________________________________________
# layer_normalization_101 (LayerN (None, 32, 32, 16)   17          conv2d_113[0][0]
# __________________________________________________________________________________________________
# activation_105 (Activation)     (None, 32, 32, 16)   0           layer_normalization_101[0][0]
# __________________________________________________________________________________________________
# conv2d_114 (Conv2D)             (None, 32, 32, 32)   4608        activation_105[0][0]
# __________________________________________________________________________________________________
# dropout_25 (Dropout)            (None, 32, 32, 32)   0           conv2d_114[0][0]
# __________________________________________________________________________________________________
# layer_normalization_102 (LayerN (None, 32, 32, 32)   33          dropout_25[0][0]
# __________________________________________________________________________________________________
# activation_106 (Activation)     (None, 32, 32, 32)   0           layer_normalization_102[0][0]
# __________________________________________________________________________________________________
# conv2d_116 (Conv2D)             (None, 32, 32, 32)   512         conv2d_113[0][0]
# __________________________________________________________________________________________________
# conv2d_115 (Conv2D)             (None, 32, 32, 32)   9216        activation_106[0][0]
# __________________________________________________________________________________________________
# add_49 (Add)                    (None, 32, 32, 32)   0           conv2d_116[0][0]
#                                                                  conv2d_115[0][0]
# __________________________________________________________________________________________________
# layer_normalization_103 (LayerN (None, 32, 32, 32)   33          add_49[0][0]
# __________________________________________________________________________________________________
# activation_107 (Activation)     (None, 32, 32, 32)   0           layer_normalization_103[0][0]
# __________________________________________________________________________________________________
# conv2d_117 (Conv2D)             (None, 32, 32, 32)   9216        activation_107[0][0]
# __________________________________________________________________________________________________
# dropout_26 (Dropout)            (None, 32, 32, 32)   0           conv2d_117[0][0]
# __________________________________________________________________________________________________
# layer_normalization_104 (LayerN (None, 32, 32, 32)   33          dropout_26[0][0]
# __________________________________________________________________________________________________
# activation_108 (Activation)     (None, 32, 32, 32)   0           layer_normalization_104[0][0]
# __________________________________________________________________________________________________
# conv2d_118 (Conv2D)             (None, 32, 32, 32)   9216        activation_108[0][0]
# __________________________________________________________________________________________________
# add_50 (Add)                    (None, 32, 32, 32)   0           add_49[0][0]
#                                                                  conv2d_118[0][0]
# __________________________________________________________________________________________________
# layer_normalization_105 (LayerN (None, 32, 32, 32)   33          add_50[0][0]
# __________________________________________________________________________________________________
# activation_109 (Activation)     (None, 32, 32, 32)   0           layer_normalization_105[0][0]
# __________________________________________________________________________________________________
# conv2d_119 (Conv2D)             (None, 32, 32, 32)   9216        activation_109[0][0]
# __________________________________________________________________________________________________
# dropout_27 (Dropout)            (None, 32, 32, 32)   0           conv2d_119[0][0]
# __________________________________________________________________________________________________
# layer_normalization_106 (LayerN (None, 32, 32, 32)   33          dropout_27[0][0]
# __________________________________________________________________________________________________
# activation_110 (Activation)     (None, 32, 32, 32)   0           layer_normalization_106[0][0]
# __________________________________________________________________________________________________
# conv2d_120 (Conv2D)             (None, 32, 32, 32)   9216        activation_110[0][0]
# __________________________________________________________________________________________________
# add_51 (Add)                    (None, 32, 32, 32)   0           add_50[0][0]
#                                                                  conv2d_120[0][0]
# __________________________________________________________________________________________________
# layer_normalization_107 (LayerN (None, 32, 32, 32)   33          add_51[0][0]
# __________________________________________________________________________________________________
# activation_111 (Activation)     (None, 32, 32, 32)   0           layer_normalization_107[0][0]
# __________________________________________________________________________________________________
# conv2d_121 (Conv2D)             (None, 32, 32, 32)   9216        activation_111[0][0]
# __________________________________________________________________________________________________
# dropout_28 (Dropout)            (None, 32, 32, 32)   0           conv2d_121[0][0]
# __________________________________________________________________________________________________
# layer_normalization_108 (LayerN (None, 32, 32, 32)   33          dropout_28[0][0]
# __________________________________________________________________________________________________
# activation_112 (Activation)     (None, 32, 32, 32)   0           layer_normalization_108[0][0]
# __________________________________________________________________________________________________
# conv2d_122 (Conv2D)             (None, 32, 32, 32)   9216        activation_112[0][0]
# __________________________________________________________________________________________________
# add_52 (Add)                    (None, 32, 32, 32)   0           add_51[0][0]
#                                                                  conv2d_122[0][0]
# __________________________________________________________________________________________________
# layer_normalization_109 (LayerN (None, 32, 32, 32)   33          add_52[0][0]
# __________________________________________________________________________________________________
# activation_113 (Activation)     (None, 32, 32, 32)   0           layer_normalization_109[0][0]
# __________________________________________________________________________________________________
# conv2d_123 (Conv2D)             (None, 16, 16, 64)   18432       activation_113[0][0]
# __________________________________________________________________________________________________
# dropout_29 (Dropout)            (None, 16, 16, 64)   0           conv2d_123[0][0]
# __________________________________________________________________________________________________
# layer_normalization_110 (LayerN (None, 16, 16, 64)   65          dropout_29[0][0]
# __________________________________________________________________________________________________
# activation_114 (Activation)     (None, 16, 16, 64)   0           layer_normalization_110[0][0]
# __________________________________________________________________________________________________
# conv2d_125 (Conv2D)             (None, 16, 16, 64)   2048        add_52[0][0]
# __________________________________________________________________________________________________
# conv2d_124 (Conv2D)             (None, 16, 16, 64)   36864       activation_114[0][0]
# __________________________________________________________________________________________________
# add_53 (Add)                    (None, 16, 16, 64)   0           conv2d_125[0][0]
#                                                                  conv2d_124[0][0]
# __________________________________________________________________________________________________
# layer_normalization_111 (LayerN (None, 16, 16, 64)   65          add_53[0][0]
# __________________________________________________________________________________________________
# activation_115 (Activation)     (None, 16, 16, 64)   0           layer_normalization_111[0][0]
# __________________________________________________________________________________________________
# conv2d_126 (Conv2D)             (None, 16, 16, 64)   36864       activation_115[0][0]
# __________________________________________________________________________________________________
# dropout_30 (Dropout)            (None, 16, 16, 64)   0           conv2d_126[0][0]
# __________________________________________________________________________________________________
# layer_normalization_112 (LayerN (None, 16, 16, 64)   65          dropout_30[0][0]
# __________________________________________________________________________________________________
# activation_116 (Activation)     (None, 16, 16, 64)   0           layer_normalization_112[0][0]
# __________________________________________________________________________________________________
# conv2d_127 (Conv2D)             (None, 16, 16, 64)   36864       activation_116[0][0]
# __________________________________________________________________________________________________
# add_54 (Add)                    (None, 16, 16, 64)   0           add_53[0][0]
#                                                                  conv2d_127[0][0]
# __________________________________________________________________________________________________
# layer_normalization_113 (LayerN (None, 16, 16, 64)   65          add_54[0][0]
# __________________________________________________________________________________________________
# activation_117 (Activation)     (None, 16, 16, 64)   0           layer_normalization_113[0][0]
# __________________________________________________________________________________________________
# conv2d_128 (Conv2D)             (None, 16, 16, 64)   36864       activation_117[0][0]
# __________________________________________________________________________________________________
# dropout_31 (Dropout)            (None, 16, 16, 64)   0           conv2d_128[0][0]
# __________________________________________________________________________________________________
# layer_normalization_114 (LayerN (None, 16, 16, 64)   65          dropout_31[0][0]
# __________________________________________________________________________________________________
# activation_118 (Activation)     (None, 16, 16, 64)   0           layer_normalization_114[0][0]
# __________________________________________________________________________________________________
# conv2d_129 (Conv2D)             (None, 16, 16, 64)   36864       activation_118[0][0]
# __________________________________________________________________________________________________
# add_55 (Add)                    (None, 16, 16, 64)   0           add_54[0][0]
#                                                                  conv2d_129[0][0]
# __________________________________________________________________________________________________
# layer_normalization_115 (LayerN (None, 16, 16, 64)   65          add_55[0][0]
# __________________________________________________________________________________________________
# activation_119 (Activation)     (None, 16, 16, 64)   0           layer_normalization_115[0][0]
# __________________________________________________________________________________________________
# conv2d_130 (Conv2D)             (None, 16, 16, 64)   36864       activation_119[0][0]
# __________________________________________________________________________________________________
# dropout_32 (Dropout)            (None, 16, 16, 64)   0           conv2d_130[0][0]
# __________________________________________________________________________________________________
# layer_normalization_116 (LayerN (None, 16, 16, 64)   65          dropout_32[0][0]
# __________________________________________________________________________________________________
# activation_120 (Activation)     (None, 16, 16, 64)   0           layer_normalization_116[0][0]
# __________________________________________________________________________________________________
# conv2d_131 (Conv2D)             (None, 16, 16, 64)   36864       activation_120[0][0]
# __________________________________________________________________________________________________
# add_56 (Add)                    (None, 16, 16, 64)   0           add_55[0][0]
#                                                                  conv2d_131[0][0]
# __________________________________________________________________________________________________
# layer_normalization_117 (LayerN (None, 16, 16, 64)   65          add_56[0][0]
# __________________________________________________________________________________________________
# activation_121 (Activation)     (None, 16, 16, 64)   0           layer_normalization_117[0][0]
# __________________________________________________________________________________________________
# conv2d_132 (Conv2D)             (None, 8, 8, 128)    73728       activation_121[0][0]
# __________________________________________________________________________________________________
# dropout_33 (Dropout)            (None, 8, 8, 128)    0           conv2d_132[0][0]
# __________________________________________________________________________________________________
# layer_normalization_118 (LayerN (None, 8, 8, 128)    129         dropout_33[0][0]
# __________________________________________________________________________________________________
# activation_122 (Activation)     (None, 8, 8, 128)    0           layer_normalization_118[0][0]
# __________________________________________________________________________________________________
# conv2d_134 (Conv2D)             (None, 8, 8, 128)    8192        add_56[0][0]
# __________________________________________________________________________________________________
# conv2d_133 (Conv2D)             (None, 8, 8, 128)    147456      activation_122[0][0]
# __________________________________________________________________________________________________
# add_57 (Add)                    (None, 8, 8, 128)    0           conv2d_134[0][0]
#                                                                  conv2d_133[0][0]
# __________________________________________________________________________________________________
# layer_normalization_119 (LayerN (None, 8, 8, 128)    129         add_57[0][0]
# __________________________________________________________________________________________________
# activation_123 (Activation)     (None, 8, 8, 128)    0           layer_normalization_119[0][0]
# __________________________________________________________________________________________________
# conv2d_135 (Conv2D)             (None, 8, 8, 128)    147456      activation_123[0][0]
# __________________________________________________________________________________________________
# dropout_34 (Dropout)            (None, 8, 8, 128)    0           conv2d_135[0][0]
# __________________________________________________________________________________________________
# layer_normalization_120 (LayerN (None, 8, 8, 128)    129         dropout_34[0][0]
# __________________________________________________________________________________________________
# activation_124 (Activation)     (None, 8, 8, 128)    0           layer_normalization_120[0][0]
# __________________________________________________________________________________________________
# conv2d_136 (Conv2D)             (None, 8, 8, 128)    147456      activation_124[0][0]
# __________________________________________________________________________________________________
# add_58 (Add)                    (None, 8, 8, 128)    0           add_57[0][0]
#                                                                  conv2d_136[0][0]
# __________________________________________________________________________________________________
# layer_normalization_121 (LayerN (None, 8, 8, 128)    129         add_58[0][0]
# __________________________________________________________________________________________________
# activation_125 (Activation)     (None, 8, 8, 128)    0           layer_normalization_121[0][0]
# __________________________________________________________________________________________________
# conv2d_137 (Conv2D)             (None, 8, 8, 128)    147456      activation_125[0][0]
# __________________________________________________________________________________________________
# dropout_35 (Dropout)            (None, 8, 8, 128)    0           conv2d_137[0][0]
# __________________________________________________________________________________________________
# layer_normalization_122 (LayerN (None, 8, 8, 128)    129         dropout_35[0][0]
# __________________________________________________________________________________________________
# activation_126 (Activation)     (None, 8, 8, 128)    0           layer_normalization_122[0][0]
# __________________________________________________________________________________________________
# conv2d_138 (Conv2D)             (None, 8, 8, 128)    147456      activation_126[0][0]
# __________________________________________________________________________________________________
# add_59 (Add)                    (None, 8, 8, 128)    0           add_58[0][0]
#                                                                  conv2d_138[0][0]
# __________________________________________________________________________________________________
# layer_normalization_123 (LayerN (None, 8, 8, 128)    129         add_59[0][0]
# __________________________________________________________________________________________________
# activation_127 (Activation)     (None, 8, 8, 128)    0           layer_normalization_123[0][0]
# __________________________________________________________________________________________________
# conv2d_139 (Conv2D)             (None, 8, 8, 128)    147456      activation_127[0][0]
# __________________________________________________________________________________________________
# dropout_36 (Dropout)            (None, 8, 8, 128)    0           conv2d_139[0][0]
# __________________________________________________________________________________________________
# layer_normalization_124 (LayerN (None, 8, 8, 128)    129         dropout_36[0][0]
# __________________________________________________________________________________________________
# activation_128 (Activation)     (None, 8, 8, 128)    0           layer_normalization_124[0][0]
# __________________________________________________________________________________________________
# conv2d_140 (Conv2D)             (None, 8, 8, 128)    147456      activation_128[0][0]
# __________________________________________________________________________________________________
# add_60 (Add)                    (None, 8, 8, 128)    0           add_59[0][0]
#                                                                  conv2d_140[0][0]
# __________________________________________________________________________________________________
# layer_normalization_125 (LayerN (None, 8, 8, 128)    129         add_60[0][0]
# __________________________________________________________________________________________________
# activation_129 (Activation)     (None, 8, 8, 128)    0           layer_normalization_125[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_5 (Glo (None, 128)          0           activation_129[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 10)           1290        global_average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# activation_130 (Activation)     (None, 10)           0           dense_5[0][0]
# ==================================================================================================
# Total params: 1,465,827
# Trainable params: 1,465,827
# Non-trainable params: 0
# __________________________________________________________________________________________________
# [NOTICE]: You are using BatchNormalization and/or Dropout.
# Those layers may affect the importance calculations and you are advised to exchange them for LayerNormalization or BatchNormalization in test mode and L2 regularization.
# Epoch 1/1000000
# 391/391 [==============================] - 68s 174ms/step - loss: 2.8522 - accuracy: 0.1453 - val_loss: 1.9877 - val_accuracy: 0.2095
# Epoch 2/1000000
# 391/391 [==============================] - 63s 161ms/step - loss: 2.1884 - accuracy: 0.2686 - val_loss: 1.8400 - val_accuracy: 0.2976
# Epoch 3/1000000
# 391/391 [==============================] - 62s 160ms/step - loss: 1.9094 - accuracy: 0.3422 - val_loss: 1.7465 - val_accuracy: 0.3611
# Epoch 4/1000000
# 391/391 [==============================] - 63s 160ms/step - loss: 1.7519 - accuracy: 0.3947 - val_loss: 1.5387 - val_accuracy: 0.4187
# Epoch 5/1000000
# 391/391 [==============================] - 63s 160ms/step - loss: 1.6205 - accuracy: 0.4541 - val_loss: 1.4186 - val_accuracy: 0.4756
# Epoch 6/1000000
# 391/391 [==============================] - 62s 159ms/step - loss: 1.4923 - accuracy: 0.5095 - val_loss: 1.1426 - val_accuracy: 0.5807
# Epoch 7/1000000
# 391/391 [==============================] - 62s 160ms/step - loss: 1.4237 - accuracy: 0.5482 - val_loss: 1.2109 - val_accuracy: 0.5635
# Epoch 8/1000000
# 391/391 [==============================] - 62s 159ms/step - loss: 1.3510 - accuracy: 0.5848 - val_loss: 1.1224 - val_accuracy: 0.5958
# Epoch 9/1000000
# 391/391 [==============================] - 62s 160ms/step - loss: 1.2996 - accuracy: 0.6112 - val_loss: 1.1426 - val_accuracy: 0.6088
# Epoch 10/1000000
# 391/391 [==============================] - 62s 160ms/step - loss: 1.2728 - accuracy: 0.6266 - val_loss: 1.0339 - val_accuracy: 0.6380
# Epoch 11/1000000
# 391/391 [==============================] - 62s 159ms/step - loss: 1.2374 - accuracy: 0.6472 - val_loss: 0.9429 - val_accuracy: 0.6700
# Epoch 12/1000000
# 391/391 [==============================] - 62s 159ms/step - loss: 1.2222 - accuracy: 0.6567 - val_loss: 0.9652 - val_accuracy: 0.6588
# Epoch 13/1000000
# 391/391 [==============================] - 62s 159ms/step - loss: 1.1881 - accuracy: 0.6729 - val_loss: 0.8988 - val_accuracy: 0.6862
# Epoch 14/1000000
# 391/391 [==============================] - 62s 159ms/step - loss: 1.1703 - accuracy: 0.6865 - val_loss: 0.8801 - val_accuracy: 0.6908
# Epoch 15/1000000
# 391/391 [==============================] - 62s 160ms/step - loss: 1.1585 - accuracy: 0.6957 - val_loss: 0.8668 - val_accuracy: 0.7003
# Epoch 16/1000000
# 391/391 [==============================] - 62s 160ms/step - loss: 1.1322 - accuracy: 0.7126 - val_loss: 0.9154 - val_accuracy: 0.6948
# Epoch 17/1000000
# 391/391 [==============================] - 63s 160ms/step - loss: 1.1189 - accuracy: 0.7239 - val_loss: 0.8426 - val_accuracy: 0.7102
# Epoch 18/1000000
# 391/391 [==============================] - 62s 160ms/step - loss: 1.1104 - accuracy: 0.7327 - val_loss: 0.9363 - val_accuracy: 0.6914
# Epoch 19/1000000
# 391/391 [==============================] - 62s 160ms/step - loss: 1.0819 - accuracy: 0.7427 - val_loss: 0.7269 - val_accuracy: 0.7556
# Epoch 20/1000000
# 391/391 [==============================] - 63s 160ms/step - loss: 1.0777 - accuracy: 0.7486 - val_loss: 0.7991 - val_accuracy: 0.7339
# Epoch 21/1000000
# 391/391 [==============================] - 62s 160ms/step - loss: 1.0676 - accuracy: 0.7540 - val_loss: 0.7005 - val_accuracy: 0.7626
# Epoch 22/1000000
# 391/391 [==============================] - 62s 160ms/step - loss: 1.0690 - accuracy: 0.7568 - val_loss: 0.6652 - val_accuracy: 0.7700
# Epoch 23/1000000
# 391/391 [==============================] - 63s 160ms/step - loss: 1.0683 - accuracy: 0.7595 - val_loss: 0.7111 - val_accuracy: 0.7541
# Epoch 24/1000000
# 391/391 [==============================] - 63s 160ms/step - loss: 1.0529 - accuracy: 0.7642 - val_loss: 0.7312 - val_accuracy: 0.7517
# Epoch 25/1000000
# 391/391 [==============================] - 62s 159ms/step - loss: 1.0588 - accuracy: 0.7674 - val_loss: 0.6950 - val_accuracy: 0.7661
# Epoch 26/1000000
# 391/391 [==============================] - 62s 159ms/step - loss: 1.0481 - accuracy: 0.7716 - val_loss: 0.6031 - val_accuracy: 0.7936
# Epoch 27/1000000
# 391/391 [==============================] - 63s 160ms/step - loss: 1.0502 - accuracy: 0.7696 - val_loss: 0.7075 - val_accuracy: 0.7596
# Epoch 28/1000000
# 391/391 [==============================] - 62s 159ms/step - loss: 1.0490 - accuracy: 0.7721 - val_loss: 0.6115 - val_accuracy: 0.7949
# Epoch 29/1000000
# 391/391 [==============================] - 62s 160ms/step - loss: 0.9921 - accuracy: 0.7908 - val_loss: 0.4820 - val_accuracy: 0.8358
# Epoch 30/1000000
# 391/391 [==============================] - 62s 160ms/step - loss: 0.7802 - accuracy: 0.8521 - val_loss: 0.4661 - val_accuracy: 0.8464
# Epoch 31/1000000
# 391/391 [==============================] - 62s 160ms/step - loss: 0.7139 - accuracy: 0.8622 - val_loss: 0.4474 - val_accuracy: 0.8510
# Epoch 32/1000000
# 391/391 [==============================] - 63s 160ms/step - loss: 0.6807 - accuracy: 0.8627 - val_loss: 0.4384 - val_accuracy: 0.8544
# Epoch 33/1000000
# 391/391 [==============================] - 62s 160ms/step - loss: 0.6567 - accuracy: 0.8661 - val_loss: 0.3969 - val_accuracy: 0.8655
# Epoch 34/1000000
# 391/391 [==============================] - 62s 159ms/step - loss: 0.6330 - accuracy: 0.8682 - val_loss: 0.4468 - val_accuracy: 0.8524
# Epoch 35/1000000
# 391/391 [==============================] - 62s 160ms/step - loss: 0.6302 - accuracy: 0.8660 - val_loss: 0.4546 - val_accuracy: 0.8456
# Epoch 36/1000000
# 391/391 [==============================] - 62s 160ms/step - loss: 0.6200 - accuracy: 0.8675 - val_loss: 0.4255 - val_accuracy: 0.8567
# Epoch 37/1000000
# 391/391 [==============================] - 62s 160ms/step - loss: 0.6086 - accuracy: 0.8705 - val_loss: 0.4119 - val_accuracy: 0.8619
# Epoch 38/1000000
# 391/391 [==============================] - 62s 159ms/step - loss: 0.6121 - accuracy: 0.8682 - val_loss: 0.4217 - val_accuracy: 0.8574
# Epoch 39/1000000
# 391/391 [==============================] - 62s 159ms/step - loss: 0.6073 - accuracy: 0.8697 - val_loss: 0.4530 - val_accuracy: 0.8509
# Epoch 40/1000000
# 391/391 [==============================] - 64s 163ms/step - loss: 0.6002 - accuracy: 0.8703 - val_loss: 0.4209 - val_accuracy: 0.8576
# Epoch 41/1000000
# 391/391 [==============================] - 63s 162ms/step - loss: 0.6047 - accuracy: 0.8697 - val_loss: 0.3967 - val_accuracy: 0.8681
# Epoch 42/1000000
# 391/391 [==============================] - 63s 162ms/step - loss: 0.6025 - accuracy: 0.8713 - val_loss: 0.5700 - val_accuracy: 0.8066
# Epoch 43/1000000
# 391/391 [==============================] - 63s 161ms/step - loss: 0.5964 - accuracy: 0.8743 - val_loss: 0.5011 - val_accuracy: 0.8392
# Epoch 44/1000000
# 391/391 [==============================] - 63s 162ms/step - loss: 0.6098 - accuracy: 0.8694 - val_loss: 0.3958 - val_accuracy: 0.8659
# Epoch 45/1000000
# 391/391 [==============================] - 63s 162ms/step - loss: 0.5961 - accuracy: 0.8740 - val_loss: 0.4308 - val_accuracy: 0.8559
# Epoch 46/1000000
# 391/391 [==============================] - 63s 162ms/step - loss: 0.5932 - accuracy: 0.8758 - val_loss: 0.3574 - val_accuracy: 0.8808
# Epoch 47/1000000
# 391/391 [==============================] - 98s 250ms/step - loss: 0.4669 - accuracy: 0.5121 - val_loss: 0.3226 - val_accuracy: 0.8938
# Epoch 48/1000000
# 391/391 [==============================] - 98s 251ms/step - loss: 0.4336 - accuracy: 0.5189 - val_loss: 0.3162 - val_accuracy: 0.8960
# Epoch 49/1000000
# 391/391 [==============================] - 98s 251ms/step - loss: 0.4176 - accuracy: 0.5266 - val_loss: 0.3053 - val_accuracy: 0.9038
# Epoch 50/1000000
# 391/391 [==============================] - 98s 252ms/step - loss: 0.4008 - accuracy: 0.5310 - val_loss: 0.3085 - val_accuracy: 0.9019
# Epoch 51/1000000
# 391/391 [==============================] - 98s 250ms/step - loss: 0.3883 - accuracy: 0.5379 - val_loss: 0.3192 - val_accuracy: 0.8986
# Epoch 52/1000000
# 391/391 [==============================] - 98s 250ms/step - loss: 0.3815 - accuracy: 0.5354 - val_loss: 0.3582 - val_accuracy: 0.8886
# Epoch 53/1000000
# 391/391 [==============================] - 98s 250ms/step - loss: 0.3802 - accuracy: 0.5383 - val_loss: 0.3165 - val_accuracy: 0.8982
# Epoch 54/1000000
#  99/391 [======>.......................] - ETA: 1:18 - loss: 0.3673 - accuracy: 0.5390 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00

# %%
# Test the model
x_test, y_test = dset.test_data[:]
eval_model(model, x_test, y_test)
# Out:
# 10000/10000 [==============================] - 6s 568us/step
# Test loss: 0.5215594121217728
# Test accuracy: 0.8974

# %%
# Save model
save(model, history, 'res-net-28-2-1hr-dropout-IS', True)

# %%
# Load model and draw plots 
path = "gdrive/My Drive/"
file_name = "res-net-28-2-1hr-dropout-IS"
model = load_model(path + file_name + ".h5", custom_objects = {'LayerNormalization' : LayerNormalization})

# Display Saved plots
listOfImageNames = [path + file_name + "-acc.png",
                    path + file_name + "-loss.png"]

for imageName in listOfImageNames:
    display(Image(filename=imageName))
    
# Load history
history = np.load(path + file_name + "-history.npy")

# %% [markdown]
# ### Wide ResNet 28-2 with 0.3 dropout and max time of 1 hr (without IS)

# %%
args = Args(depth = 28, width = 2, presample = 3.0, batch_size = 128, time_budget = 1, dropout = 0.3, useIS = False)
model, history = build_wide_res(args, dset)
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 32, 32, 16)   432         input_6[0][0]
# __________________________________________________________________________________________________
# layer_normalization_76 (LayerNo (None, 32, 32, 16)   17          conv2d_85[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 32, 32, 16)   0           layer_normalization_76[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 32, 32, 32)   4608        activation_79[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 32, 32, 32)   0           conv2d_86[0][0]
# __________________________________________________________________________________________________
# layer_normalization_77 (LayerNo (None, 32, 32, 32)   33          dropout_13[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 32, 32, 32)   0           layer_normalization_77[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 32, 32, 32)   512         conv2d_85[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 32, 32, 32)   9216        activation_80[0][0]
# __________________________________________________________________________________________________
# add_37 (Add)                    (None, 32, 32, 32)   0           conv2d_88[0][0]
#                                                                  conv2d_87[0][0]
# __________________________________________________________________________________________________
# layer_normalization_78 (LayerNo (None, 32, 32, 32)   33          add_37[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 32, 32, 32)   0           layer_normalization_78[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 32, 32, 32)   9216        activation_81[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 32, 32, 32)   0           conv2d_89[0][0]
# __________________________________________________________________________________________________
# layer_normalization_79 (LayerNo (None, 32, 32, 32)   33          dropout_14[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 32, 32, 32)   0           layer_normalization_79[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 32, 32, 32)   9216        activation_82[0][0]
# __________________________________________________________________________________________________
# add_38 (Add)                    (None, 32, 32, 32)   0           add_37[0][0]
#                                                                  conv2d_90[0][0]
# __________________________________________________________________________________________________
# layer_normalization_80 (LayerNo (None, 32, 32, 32)   33          add_38[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 32, 32, 32)   0           layer_normalization_80[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 32, 32, 32)   9216        activation_83[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 32, 32, 32)   0           conv2d_91[0][0]
# __________________________________________________________________________________________________
# layer_normalization_81 (LayerNo (None, 32, 32, 32)   33          dropout_15[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 32, 32, 32)   0           layer_normalization_81[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 32, 32, 32)   9216        activation_84[0][0]
# __________________________________________________________________________________________________
# add_39 (Add)                    (None, 32, 32, 32)   0           add_38[0][0]
#                                                                  conv2d_92[0][0]
# __________________________________________________________________________________________________
# layer_normalization_82 (LayerNo (None, 32, 32, 32)   33          add_39[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, 32, 32, 32)   0           layer_normalization_82[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 32, 32, 32)   9216        activation_85[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 32, 32, 32)   0           conv2d_93[0][0]
# __________________________________________________________________________________________________
# layer_normalization_83 (LayerNo (None, 32, 32, 32)   33          dropout_16[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, 32, 32, 32)   0           layer_normalization_83[0][0]
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 32, 32, 32)   9216        activation_86[0][0]
# __________________________________________________________________________________________________
# add_40 (Add)                    (None, 32, 32, 32)   0           add_39[0][0]
#                                                                  conv2d_94[0][0]
# __________________________________________________________________________________________________
# layer_normalization_84 (LayerNo (None, 32, 32, 32)   33          add_40[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 32, 32, 32)   0           layer_normalization_84[0][0]
# __________________________________________________________________________________________________
# conv2d_95 (Conv2D)              (None, 16, 16, 64)   18432       activation_87[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 16, 16, 64)   0           conv2d_95[0][0]
# __________________________________________________________________________________________________
# layer_normalization_85 (LayerNo (None, 16, 16, 64)   65          dropout_17[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 16, 16, 64)   0           layer_normalization_85[0][0]
# __________________________________________________________________________________________________
# conv2d_97 (Conv2D)              (None, 16, 16, 64)   2048        add_40[0][0]
# __________________________________________________________________________________________________
# conv2d_96 (Conv2D)              (None, 16, 16, 64)   36864       activation_88[0][0]
# __________________________________________________________________________________________________
# add_41 (Add)                    (None, 16, 16, 64)   0           conv2d_97[0][0]
#                                                                  conv2d_96[0][0]
# __________________________________________________________________________________________________
# layer_normalization_86 (LayerNo (None, 16, 16, 64)   65          add_41[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 16, 16, 64)   0           layer_normalization_86[0][0]
# __________________________________________________________________________________________________
# conv2d_98 (Conv2D)              (None, 16, 16, 64)   36864       activation_89[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 16, 16, 64)   0           conv2d_98[0][0]
# __________________________________________________________________________________________________
# layer_normalization_87 (LayerNo (None, 16, 16, 64)   65          dropout_18[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 16, 16, 64)   0           layer_normalization_87[0][0]
# __________________________________________________________________________________________________
# conv2d_99 (Conv2D)              (None, 16, 16, 64)   36864       activation_90[0][0]
# __________________________________________________________________________________________________
# add_42 (Add)                    (None, 16, 16, 64)   0           add_41[0][0]
#                                                                  conv2d_99[0][0]
# __________________________________________________________________________________________________
# layer_normalization_88 (LayerNo (None, 16, 16, 64)   65          add_42[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 16, 16, 64)   0           layer_normalization_88[0][0]
# __________________________________________________________________________________________________
# conv2d_100 (Conv2D)             (None, 16, 16, 64)   36864       activation_91[0][0]
# __________________________________________________________________________________________________
# dropout_19 (Dropout)            (None, 16, 16, 64)   0           conv2d_100[0][0]
# __________________________________________________________________________________________________
# layer_normalization_89 (LayerNo (None, 16, 16, 64)   65          dropout_19[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 16, 16, 64)   0           layer_normalization_89[0][0]
# __________________________________________________________________________________________________
# conv2d_101 (Conv2D)             (None, 16, 16, 64)   36864       activation_92[0][0]
# __________________________________________________________________________________________________
# add_43 (Add)                    (None, 16, 16, 64)   0           add_42[0][0]
#                                                                  conv2d_101[0][0]
# __________________________________________________________________________________________________
# layer_normalization_90 (LayerNo (None, 16, 16, 64)   65          add_43[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 16, 16, 64)   0           layer_normalization_90[0][0]
# __________________________________________________________________________________________________
# conv2d_102 (Conv2D)             (None, 16, 16, 64)   36864       activation_93[0][0]
# __________________________________________________________________________________________________
# dropout_20 (Dropout)            (None, 16, 16, 64)   0           conv2d_102[0][0]
# __________________________________________________________________________________________________
# layer_normalization_91 (LayerNo (None, 16, 16, 64)   65          dropout_20[0][0]
# __________________________________________________________________________________________________
# activation_94 (Activation)      (None, 16, 16, 64)   0           layer_normalization_91[0][0]
# __________________________________________________________________________________________________
# conv2d_103 (Conv2D)             (None, 16, 16, 64)   36864       activation_94[0][0]
# __________________________________________________________________________________________________
# add_44 (Add)                    (None, 16, 16, 64)   0           add_43[0][0]
#                                                                  conv2d_103[0][0]
# __________________________________________________________________________________________________
# layer_normalization_92 (LayerNo (None, 16, 16, 64)   65          add_44[0][0]
# __________________________________________________________________________________________________
# activation_95 (Activation)      (None, 16, 16, 64)   0           layer_normalization_92[0][0]
# __________________________________________________________________________________________________
# conv2d_104 (Conv2D)             (None, 8, 8, 128)    73728       activation_95[0][0]
# __________________________________________________________________________________________________
# dropout_21 (Dropout)            (None, 8, 8, 128)    0           conv2d_104[0][0]
# __________________________________________________________________________________________________
# layer_normalization_93 (LayerNo (None, 8, 8, 128)    129         dropout_21[0][0]
# __________________________________________________________________________________________________
# activation_96 (Activation)      (None, 8, 8, 128)    0           layer_normalization_93[0][0]
# __________________________________________________________________________________________________
# conv2d_106 (Conv2D)             (None, 8, 8, 128)    8192        add_44[0][0]
# __________________________________________________________________________________________________
# conv2d_105 (Conv2D)             (None, 8, 8, 128)    147456      activation_96[0][0]
# __________________________________________________________________________________________________
# add_45 (Add)                    (None, 8, 8, 128)    0           conv2d_106[0][0]
#                                                                  conv2d_105[0][0]
# __________________________________________________________________________________________________
# layer_normalization_94 (LayerNo (None, 8, 8, 128)    129         add_45[0][0]
# __________________________________________________________________________________________________
# activation_97 (Activation)      (None, 8, 8, 128)    0           layer_normalization_94[0][0]
# __________________________________________________________________________________________________
# conv2d_107 (Conv2D)             (None, 8, 8, 128)    147456      activation_97[0][0]
# __________________________________________________________________________________________________
# dropout_22 (Dropout)            (None, 8, 8, 128)    0           conv2d_107[0][0]
# __________________________________________________________________________________________________
# layer_normalization_95 (LayerNo (None, 8, 8, 128)    129         dropout_22[0][0]
# __________________________________________________________________________________________________
# activation_98 (Activation)      (None, 8, 8, 128)    0           layer_normalization_95[0][0]
# __________________________________________________________________________________________________
# conv2d_108 (Conv2D)             (None, 8, 8, 128)    147456      activation_98[0][0]
# __________________________________________________________________________________________________
# add_46 (Add)                    (None, 8, 8, 128)    0           add_45[0][0]
#                                                                  conv2d_108[0][0]
# __________________________________________________________________________________________________
# layer_normalization_96 (LayerNo (None, 8, 8, 128)    129         add_46[0][0]
# __________________________________________________________________________________________________
# activation_99 (Activation)      (None, 8, 8, 128)    0           layer_normalization_96[0][0]
# __________________________________________________________________________________________________
# conv2d_109 (Conv2D)             (None, 8, 8, 128)    147456      activation_99[0][0]
# __________________________________________________________________________________________________
# dropout_23 (Dropout)            (None, 8, 8, 128)    0           conv2d_109[0][0]
# __________________________________________________________________________________________________
# layer_normalization_97 (LayerNo (None, 8, 8, 128)    129         dropout_23[0][0]
# __________________________________________________________________________________________________
# activation_100 (Activation)     (None, 8, 8, 128)    0           layer_normalization_97[0][0]
# __________________________________________________________________________________________________
# conv2d_110 (Conv2D)             (None, 8, 8, 128)    147456      activation_100[0][0]
# __________________________________________________________________________________________________
# add_47 (Add)                    (None, 8, 8, 128)    0           add_46[0][0]
#                                                                  conv2d_110[0][0]
# __________________________________________________________________________________________________
# layer_normalization_98 (LayerNo (None, 8, 8, 128)    129         add_47[0][0]
# __________________________________________________________________________________________________
# activation_101 (Activation)     (None, 8, 8, 128)    0           layer_normalization_98[0][0]
# __________________________________________________________________________________________________
# conv2d_111 (Conv2D)             (None, 8, 8, 128)    147456      activation_101[0][0]
# __________________________________________________________________________________________________
# dropout_24 (Dropout)            (None, 8, 8, 128)    0           conv2d_111[0][0]
# __________________________________________________________________________________________________
# layer_normalization_99 (LayerNo (None, 8, 8, 128)    129         dropout_24[0][0]
# __________________________________________________________________________________________________
# activation_102 (Activation)     (None, 8, 8, 128)    0           layer_normalization_99[0][0]
# __________________________________________________________________________________________________
# conv2d_112 (Conv2D)             (None, 8, 8, 128)    147456      activation_102[0][0]
# __________________________________________________________________________________________________
# add_48 (Add)                    (None, 8, 8, 128)    0           add_47[0][0]
#                                                                  conv2d_112[0][0]
# __________________________________________________________________________________________________
# layer_normalization_100 (LayerN (None, 8, 8, 128)    129         add_48[0][0]
# __________________________________________________________________________________________________
# activation_103 (Activation)     (None, 8, 8, 128)    0           layer_normalization_100[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_4 (Glo (None, 128)          0           activation_103[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 10)           1290        global_average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# activation_104 (Activation)     (None, 10)           0           dense_4[0][0]
# ==================================================================================================
# Total params: 1,465,827
# Trainable params: 1,465,827
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/1000000
# 391/391 [==============================] - 67s 171ms/step - loss: 2.8821 - acc: 0.1346 - val_loss: 2.5264 - val_acc: 0.1804
# Epoch 2/1000000
# 391/391 [==============================] - 62s 159ms/step - loss: 2.1923 - acc: 0.2769 - val_loss: 2.0826 - val_acc: 0.3063
# Epoch 3/1000000
# 391/391 [==============================] - 62s 158ms/step - loss: 1.8148 - acc: 0.3906 - val_loss: 1.7776 - val_acc: 0.4000
# Epoch 4/1000000
# 391/391 [==============================] - 62s 159ms/step - loss: 1.6381 - acc: 0.4527 - val_loss: 1.4665 - val_acc: 0.5227
# Epoch 5/1000000
# 391/391 [==============================] - 62s 158ms/step - loss: 1.5238 - acc: 0.5070 - val_loss: 1.4890 - val_acc: 0.5358
# Epoch 6/1000000
# 391/391 [==============================] - 62s 158ms/step - loss: 1.4241 - acc: 0.5528 - val_loss: 1.3614 - val_acc: 0.5877
# Epoch 7/1000000
# 391/391 [==============================] - 62s 158ms/step - loss: 1.3395 - acc: 0.5936 - val_loss: 1.3200 - val_acc: 0.6019
# Epoch 8/1000000
# 391/391 [==============================] - 62s 159ms/step - loss: 1.2938 - acc: 0.6169 - val_loss: 1.2141 - val_acc: 0.6494
# Epoch 9/1000000
# 391/391 [==============================] - 62s 158ms/step - loss: 1.2789 - acc: 0.6302 - val_loss: 1.2514 - val_acc: 0.6420
# Epoch 10/1000000
# 391/391 [==============================] - 62s 158ms/step - loss: 1.2315 - acc: 0.6527 - val_loss: 1.2782 - val_acc: 0.6356
# Epoch 11/1000000
# 391/391 [==============================] - 62s 158ms/step - loss: 1.2098 - acc: 0.6648 - val_loss: 1.2935 - val_acc: 0.6513
# Epoch 12/1000000
# 391/391 [==============================] - 62s 158ms/step - loss: 1.1920 - acc: 0.6794 - val_loss: 1.1636 - val_acc: 0.6920
# Epoch 13/1000000
# 391/391 [==============================] - 62s 157ms/step - loss: 1.1567 - acc: 0.7014 - val_loss: 1.2026 - val_acc: 0.6890
# Epoch 14/1000000
# 391/391 [==============================] - 62s 158ms/step - loss: 1.1366 - acc: 0.7131 - val_loss: 1.2694 - val_acc: 0.6867
# Epoch 15/1000000
# 391/391 [==============================] - 62s 158ms/step - loss: 1.1316 - acc: 0.7204 - val_loss: 1.0243 - val_acc: 0.7619
# Epoch 16/1000000
# 391/391 [==============================] - 62s 159ms/step - loss: 1.1106 - acc: 0.7303 - val_loss: 1.0800 - val_acc: 0.7462
# Epoch 17/1000000
# 391/391 [==============================] - 62s 158ms/step - loss: 1.1007 - acc: 0.7393 - val_loss: 1.0754 - val_acc: 0.7497
# Epoch 18/1000000
# 391/391 [==============================] - 62s 158ms/step - loss: 1.0737 - acc: 0.7495 - val_loss: 1.0233 - val_acc: 0.7635
# Epoch 19/1000000
# 391/391 [==============================] - 62s 158ms/step - loss: 1.0822 - acc: 0.7520 - val_loss: 1.1496 - val_acc: 0.7300
# Epoch 20/1000000
# 391/391 [==============================] - 62s 158ms/step - loss: 1.0689 - acc: 0.7552 - val_loss: 1.0700 - val_acc: 0.7561
# Epoch 21/1000000
# 391/391 [==============================] - 62s 159ms/step - loss: 1.0677 - acc: 0.7605 - val_loss: 1.2074 - val_acc: 0.7201
# Epoch 22/1000000
# 391/391 [==============================] - 62s 158ms/step - loss: 1.0616 - acc: 0.7649 - val_loss: 1.0639 - val_acc: 0.7620
# Epoch 23/1000000
# 391/391 [==============================] - 62s 158ms/step - loss: 1.0469 - acc: 0.7673 - val_loss: 1.0643 - val_acc: 0.7632
# Epoch 24/1000000
# 391/391 [==============================] - 62s 158ms/step - loss: 1.0506 - acc: 0.7704 - val_loss: 0.9600 - val_acc: 0.8037
# Epoch 25/1000000
# 391/391 [==============================] - 62s 158ms/step - loss: 1.0599 - acc: 0.7693 - val_loss: 1.0213 - val_acc: 0.7815
# Epoch 26/1000000
# 391/391 [==============================] - 62s 158ms/step - loss: 1.0529 - acc: 0.7724 - val_loss: 1.0092 - val_acc: 0.7892
# Epoch 27/1000000
# 391/391 [==============================] - 62s 158ms/step - loss: 1.0505 - acc: 0.7757 - val_loss: 1.1343 - val_acc: 0.7404
# Epoch 28/1000000
# 391/391 [==============================] - 62s 158ms/step - loss: 1.0568 - acc: 0.7728 - val_loss: 0.9939 - val_acc: 0.7957
# Epoch 29/1000000
# 391/391 [==============================] - 62s 158ms/step - loss: 1.0509 - acc: 0.7768 - val_loss: 1.0824 - val_acc: 0.7724
# Epoch 30/1000000
# 391/391 [==============================] - 62s 158ms/step - loss: 0.8315 - acc: 0.8437 - val_loss: 0.7806 - val_acc: 0.8562
# Epoch 31/1000000
# 391/391 [==============================] - 62s 158ms/step - loss: 0.7332 - acc: 0.8639 - val_loss: 0.7406 - val_acc: 0.8578
# Epoch 32/1000000
# 391/391 [==============================] - 62s 158ms/step - loss: 0.6951 - acc: 0.8648 - val_loss: 0.7212 - val_acc: 0.8505
# Epoch 33/1000000
# 391/391 [==============================] - 62s 158ms/step - loss: 0.6593 - acc: 0.8697 - val_loss: 0.7067 - val_acc: 0.8517
# Epoch 34/1000000
# 391/391 [==============================] - 62s 158ms/step - loss: 0.6375 - acc: 0.8711 - val_loss: 0.6720 - val_acc: 0.8571
# Epoch 35/1000000
# 391/391 [==============================] - 62s 158ms/step - loss: 0.6323 - acc: 0.8678 - val_loss: 0.6770 - val_acc: 0.8516
# Epoch 36/1000000
# 391/391 [==============================] - 62s 158ms/step - loss: 0.6154 - acc: 0.8710 - val_loss: 0.6323 - val_acc: 0.8674
# Epoch 37/1000000
# 391/391 [==============================] - 62s 158ms/step - loss: 0.6113 - acc: 0.8692 - val_loss: 0.7069 - val_acc: 0.8430
# Epoch 38/1000000
# 391/391 [==============================] - 62s 158ms/step - loss: 0.6067 - acc: 0.8716 - val_loss: 0.6206 - val_acc: 0.8657
# Epoch 39/1000000
# 391/391 [==============================] - 62s 157ms/step - loss: 0.6077 - acc: 0.8710 - val_loss: 0.6161 - val_acc: 0.8691
# Epoch 40/1000000
# 391/391 [==============================] - 62s 158ms/step - loss: 0.6009 - acc: 0.8719 - val_loss: 0.6024 - val_acc: 0.8761
# Epoch 41/1000000
# 391/391 [==============================] - 62s 158ms/step - loss: 0.6004 - acc: 0.8722 - val_loss: 0.6308 - val_acc: 0.8651
# Epoch 42/1000000
# 391/391 [==============================] - 62s 158ms/step - loss: 0.5979 - acc: 0.8746 - val_loss: 0.6958 - val_acc: 0.8480
# Epoch 43/1000000
# 391/391 [==============================] - 62s 158ms/step - loss: 0.6087 - acc: 0.8713 - val_loss: 0.6600 - val_acc: 0.8599
# Epoch 44/1000000
# 391/391 [==============================] - 62s 158ms/step - loss: 0.5962 - acc: 0.8749 - val_loss: 0.6547 - val_acc: 0.8616
# Epoch 45/1000000
# 391/391 [==============================] - 62s 158ms/step - loss: 0.6021 - acc: 0.8737 - val_loss: 0.6628 - val_acc: 0.8534
# Epoch 46/1000000
# 391/391 [==============================] - 62s 158ms/step - loss: 0.6036 - acc: 0.8743 - val_loss: 0.6317 - val_acc: 0.8675
# Epoch 47/1000000
# 391/391 [==============================] - 62s 158ms/step - loss: 0.5584 - acc: 0.8906 - val_loss: 0.5578 - val_acc: 0.8908
# Epoch 48/1000000
# 391/391 [==============================] - 62s 158ms/step - loss: 0.4650 - acc: 0.9223 - val_loss: 0.5541 - val_acc: 0.8932
# Epoch 49/1000000
# 391/391 [==============================] - 62s 158ms/step - loss: 0.4482 - acc: 0.9248 - val_loss: 0.5592 - val_acc: 0.8898
# Epoch 50/1000000
# 391/391 [==============================] - 62s 158ms/step - loss: 0.4346 - acc: 0.9285 - val_loss: 0.5272 - val_acc: 0.8985
# Epoch 51/1000000
# 391/391 [==============================] - 62s 158ms/step - loss: 0.4202 - acc: 0.9313 - val_loss: 0.5406 - val_acc: 0.8936
# Epoch 52/1000000
# 391/391 [==============================] - 62s 157ms/step - loss: 0.4113 - acc: 0.9328 - val_loss: 0.5154 - val_acc: 0.9013
# Epoch 53/1000000
# 391/391 [==============================] - 62s 158ms/step - loss: 0.3957 - acc: 0.9367 - val_loss: 0.5184 - val_acc: 0.9012
# Epoch 54/1000000
# 391/391 [==============================] - 62s 158ms/step - loss: 0.3940 - acc: 0.9350 - val_loss: 0.5021 - val_acc: 0.9014
# Epoch 55/1000000
# 391/391 [==============================] - 62s 158ms/step - loss: 0.3854 - acc: 0.9375 - val_loss: 0.5112 - val_acc: 0.8963
# Epoch 56/1000000
# 391/391 [==============================] - 62s 158ms/step - loss: 0.3788 - acc: 0.9385 - val_loss: 0.5024 - val_acc: 0.9035
# Epoch 57/1000000
# 391/391 [==============================] - 62s 158ms/step - loss: 0.3755 - acc: 0.9378 - val_loss: 0.4958 - val_acc: 0.9014
# Epoch 58/1000000
# 391/391 [==============================] - 62s 158ms/step - loss: 0.3684 - acc: 0.9391 - val_loss: 0.5105 - val_acc: 0.9006
# Epoch 59/1000000
#  55/391 [===>..........................] - ETA: 51s - loss: 0.3609 - acc: 0.9406

# %%
# Test the model
x_test, y_test = dset.test_data[:]
eval_model(model, x_test, y_test)
# Out:
# 10000/10000 [==============================] - 3s 259us/step
# Test loss: 0.5106745192527771
# Test accuracy: 0.9017

# %%
# Save model
save(model, history, 'res-net-28-2-1hr-dropout-noIS', False)

# %%
# Load model and draw plots 
path = "gdrive/My Drive/"
file_name = "res-net-28-2-1hr-dropout-noIS"
model = load_model(path + file_name + ".h5", custom_objects = {'LayerNormalization' : LayerNormalization})

# Display Saved plots
listOfImageNames = [path + file_name + "-acc.png",
                    path + file_name + "-loss.png"]

for imageName in listOfImageNames:
    display(Image(filename=imageName))
    
# Load history
history = np.load(path + file_name + "-history.npy")

# %% [markdown]
# ### Wide ResNet 28-2 without dropout and max time of 1 hr (with IS)

# %%
args = Args(depth = 28, width = 2, presample = 3.0, batch_size = 128, time_budget = 1, dropout = 0, useIS = True)
model, history = build_wide_res(args, dset)
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 32, 32, 16)   432         input_2[0][0]
# __________________________________________________________________________________________________
# layer_normalization_26 (LayerNo (None, 32, 32, 16)   17          conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 32, 32, 16)   0           layer_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 32, 32, 32)   4608        activation_27[0][0]
# __________________________________________________________________________________________________
# layer_normalization_27 (LayerNo (None, 32, 32, 32)   33          conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 32, 32, 32)   0           layer_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 32, 32, 32)   512         conv2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 32, 32, 32)   9216        activation_28[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 32, 32, 32)   0           conv2d_32[0][0]
#                                                                  conv2d_31[0][0]
# __________________________________________________________________________________________________
# layer_normalization_28 (LayerNo (None, 32, 32, 32)   33          add_13[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 32, 32, 32)   0           layer_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 32, 32, 32)   9216        activation_29[0][0]
# __________________________________________________________________________________________________
# layer_normalization_29 (LayerNo (None, 32, 32, 32)   33          conv2d_33[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 32, 32, 32)   0           layer_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 32, 32, 32)   9216        activation_30[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 32, 32, 32)   0           add_13[0][0]
#                                                                  conv2d_34[0][0]
# __________________________________________________________________________________________________
# layer_normalization_30 (LayerNo (None, 32, 32, 32)   33          add_14[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 32, 32, 32)   0           layer_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 32, 32, 32)   9216        activation_31[0][0]
# __________________________________________________________________________________________________
# layer_normalization_31 (LayerNo (None, 32, 32, 32)   33          conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 32, 32, 32)   0           layer_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 32, 32, 32)   9216        activation_32[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 32, 32, 32)   0           add_14[0][0]
#                                                                  conv2d_36[0][0]
# __________________________________________________________________________________________________
# layer_normalization_32 (LayerNo (None, 32, 32, 32)   33          add_15[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 32, 32, 32)   0           layer_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 32, 32, 32)   9216        activation_33[0][0]
# __________________________________________________________________________________________________
# layer_normalization_33 (LayerNo (None, 32, 32, 32)   33          conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 32, 32, 32)   0           layer_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 32, 32, 32)   9216        activation_34[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 32, 32, 32)   0           add_15[0][0]
#                                                                  conv2d_38[0][0]
# __________________________________________________________________________________________________
# layer_normalization_34 (LayerNo (None, 32, 32, 32)   33          add_16[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 32, 32, 32)   0           layer_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 16, 16, 64)   18432       activation_35[0][0]
# __________________________________________________________________________________________________
# layer_normalization_35 (LayerNo (None, 16, 16, 64)   65          conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 16, 16, 64)   0           layer_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 16, 16, 64)   2048        add_16[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 16, 16, 64)   36864       activation_36[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 16, 16, 64)   0           conv2d_41[0][0]
#                                                                  conv2d_40[0][0]
# __________________________________________________________________________________________________
# layer_normalization_36 (LayerNo (None, 16, 16, 64)   65          add_17[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 16, 16, 64)   0           layer_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 16, 16, 64)   36864       activation_37[0][0]
# __________________________________________________________________________________________________
# layer_normalization_37 (LayerNo (None, 16, 16, 64)   65          conv2d_42[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 16, 16, 64)   0           layer_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 16, 16, 64)   36864       activation_38[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 16, 16, 64)   0           add_17[0][0]
#                                                                  conv2d_43[0][0]
# __________________________________________________________________________________________________
# layer_normalization_38 (LayerNo (None, 16, 16, 64)   65          add_18[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 16, 16, 64)   0           layer_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 16, 16, 64)   36864       activation_39[0][0]
# __________________________________________________________________________________________________
# layer_normalization_39 (LayerNo (None, 16, 16, 64)   65          conv2d_44[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 16, 16, 64)   0           layer_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 16, 16, 64)   36864       activation_40[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 16, 16, 64)   0           add_18[0][0]
#                                                                  conv2d_45[0][0]
# __________________________________________________________________________________________________
# layer_normalization_40 (LayerNo (None, 16, 16, 64)   65          add_19[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 16, 16, 64)   0           layer_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 16, 16, 64)   36864       activation_41[0][0]
# __________________________________________________________________________________________________
# layer_normalization_41 (LayerNo (None, 16, 16, 64)   65          conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 16, 16, 64)   0           layer_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 16, 16, 64)   36864       activation_42[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 16, 16, 64)   0           add_19[0][0]
#                                                                  conv2d_47[0][0]
# __________________________________________________________________________________________________
# layer_normalization_42 (LayerNo (None, 16, 16, 64)   65          add_20[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 16, 16, 64)   0           layer_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 8, 8, 128)    73728       activation_43[0][0]
# __________________________________________________________________________________________________
# layer_normalization_43 (LayerNo (None, 8, 8, 128)    129         conv2d_48[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 8, 8, 128)    0           layer_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 8, 8, 128)    8192        add_20[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 8, 8, 128)    147456      activation_44[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 8, 8, 128)    0           conv2d_50[0][0]
#                                                                  conv2d_49[0][0]
# __________________________________________________________________________________________________
# layer_normalization_44 (LayerNo (None, 8, 8, 128)    129         add_21[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 8, 8, 128)    0           layer_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 8, 8, 128)    147456      activation_45[0][0]
# __________________________________________________________________________________________________
# layer_normalization_45 (LayerNo (None, 8, 8, 128)    129         conv2d_51[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 8, 8, 128)    0           layer_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 8, 8, 128)    147456      activation_46[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 8, 8, 128)    0           add_21[0][0]
#                                                                  conv2d_52[0][0]
# __________________________________________________________________________________________________
# layer_normalization_46 (LayerNo (None, 8, 8, 128)    129         add_22[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 8, 8, 128)    0           layer_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 8, 8, 128)    147456      activation_47[0][0]
# __________________________________________________________________________________________________
# layer_normalization_47 (LayerNo (None, 8, 8, 128)    129         conv2d_53[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 8, 8, 128)    0           layer_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 8, 8, 128)    147456      activation_48[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 8, 8, 128)    0           add_22[0][0]
#                                                                  conv2d_54[0][0]
# __________________________________________________________________________________________________
# layer_normalization_48 (LayerNo (None, 8, 8, 128)    129         add_23[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 8, 8, 128)    0           layer_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 8, 8, 128)    147456      activation_49[0][0]
# __________________________________________________________________________________________________
# layer_normalization_49 (LayerNo (None, 8, 8, 128)    129         conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 8, 8, 128)    0           layer_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 8, 8, 128)    147456      activation_50[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 8, 8, 128)    0           add_23[0][0]
#                                                                  conv2d_56[0][0]
# __________________________________________________________________________________________________
# layer_normalization_50 (LayerNo (None, 8, 8, 128)    129         add_24[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 8, 8, 128)    0           layer_normalization_50[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 128)          0           activation_51[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 10)           1290        global_average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 10)           0           dense_2[0][0]
# ==================================================================================================
# Total params: 1,465,827
# Trainable params: 1,465,827
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/1000000
# 391/391 [==============================] - 61s 156ms/step - loss: 2.8280 - accuracy: 0.1549 - val_loss: 1.9699 - val_accuracy: 0.2217
# Epoch 2/1000000
# 391/391 [==============================] - 57s 147ms/step - loss: 2.2013 - accuracy: 0.2659 - val_loss: 1.7419 - val_accuracy: 0.3326
# Epoch 3/1000000
# 391/391 [==============================] - 57s 146ms/step - loss: 1.8474 - accuracy: 0.3759 - val_loss: 1.6578 - val_accuracy: 0.3749
# Epoch 4/1000000
# 391/391 [==============================] - 57s 147ms/step - loss: 1.6595 - accuracy: 0.4431 - val_loss: 1.8154 - val_accuracy: 0.3924
# Epoch 5/1000000
# 391/391 [==============================] - 57s 147ms/step - loss: 1.5384 - accuracy: 0.4981 - val_loss: 1.3396 - val_accuracy: 0.5331
# Epoch 6/1000000
# 391/391 [==============================] - 57s 147ms/step - loss: 1.4074 - accuracy: 0.5527 - val_loss: 1.1818 - val_accuracy: 0.5809
# Epoch 7/1000000
# 391/391 [==============================] - 57s 147ms/step - loss: 1.3310 - accuracy: 0.5899 - val_loss: 1.0398 - val_accuracy: 0.6239
# Epoch 8/1000000
# 391/391 [==============================] - 57s 147ms/step - loss: 1.2634 - accuracy: 0.6239 - val_loss: 1.1295 - val_accuracy: 0.6026
# Epoch 9/1000000
# 391/391 [==============================] - 57s 147ms/step - loss: 1.2374 - accuracy: 0.6398 - val_loss: 0.9984 - val_accuracy: 0.6558
# Epoch 10/1000000
# 391/391 [==============================] - 57s 147ms/step - loss: 1.1920 - accuracy: 0.6645 - val_loss: 0.8649 - val_accuracy: 0.6948
# Epoch 11/1000000
# 391/391 [==============================] - 57s 147ms/step - loss: 1.1720 - accuracy: 0.6756 - val_loss: 0.8516 - val_accuracy: 0.7032
# Epoch 12/1000000
# 391/391 [==============================] - 57s 147ms/step - loss: 1.1352 - accuracy: 0.6984 - val_loss: 1.0382 - val_accuracy: 0.6446
# Epoch 13/1000000
# 391/391 [==============================] - 57s 146ms/step - loss: 1.1130 - accuracy: 0.7110 - val_loss: 0.7902 - val_accuracy: 0.7283
# Epoch 14/1000000
# 391/391 [==============================] - 57s 147ms/step - loss: 1.0828 - accuracy: 0.7256 - val_loss: 0.7317 - val_accuracy: 0.7464
# Epoch 15/1000000
# 391/391 [==============================] - 57s 147ms/step - loss: 1.0543 - accuracy: 0.7431 - val_loss: 0.7367 - val_accuracy: 0.7500
# Epoch 16/1000000
# 391/391 [==============================] - 57s 147ms/step - loss: 1.0384 - accuracy: 0.7514 - val_loss: 0.7407 - val_accuracy: 0.7443
# Epoch 17/1000000
# 391/391 [==============================] - 57s 147ms/step - loss: 1.0292 - accuracy: 0.7582 - val_loss: 0.9585 - val_accuracy: 0.6899
# Epoch 18/1000000
# 391/391 [==============================] - 57s 147ms/step - loss: 1.0192 - accuracy: 0.7671 - val_loss: 0.6768 - val_accuracy: 0.7677
# Epoch 19/1000000
# 391/391 [==============================] - 57s 147ms/step - loss: 1.0042 - accuracy: 0.7723 - val_loss: 0.6756 - val_accuracy: 0.7738
# Epoch 20/1000000
# 391/391 [==============================] - 57s 146ms/step - loss: 0.9861 - accuracy: 0.7791 - val_loss: 0.6333 - val_accuracy: 0.7818
# Epoch 21/1000000
# 391/391 [==============================] - 57s 147ms/step - loss: 0.9893 - accuracy: 0.7812 - val_loss: 0.6593 - val_accuracy: 0.7754
# Epoch 22/1000000
# 391/391 [==============================] - 57s 147ms/step - loss: 0.9858 - accuracy: 0.7846 - val_loss: 0.5508 - val_accuracy: 0.8102
# Epoch 23/1000000
# 391/391 [==============================] - 58s 147ms/step - loss: 0.9816 - accuracy: 0.7858 - val_loss: 0.7662 - val_accuracy: 0.7471
# Epoch 24/1000000
# 391/391 [==============================] - 57s 147ms/step - loss: 0.9665 - accuracy: 0.7953 - val_loss: 0.6082 - val_accuracy: 0.7911
# Epoch 25/1000000
# 391/391 [==============================] - 57s 146ms/step - loss: 0.9632 - accuracy: 0.7950 - val_loss: 0.7086 - val_accuracy: 0.7656
# Epoch 26/1000000
# 391/391 [==============================] - 57s 147ms/step - loss: 0.9837 - accuracy: 0.7908 - val_loss: 0.6568 - val_accuracy: 0.7887
# Epoch 27/1000000
# 391/391 [==============================] - 57s 146ms/step - loss: 0.9874 - accuracy: 0.7925 - val_loss: 0.6946 - val_accuracy: 0.7589
# Epoch 28/1000000
# 391/391 [==============================] - 58s 147ms/step - loss: 0.9694 - accuracy: 0.7993 - val_loss: 0.7197 - val_accuracy: 0.7658
# Epoch 29/1000000
# 391/391 [==============================] - 57s 147ms/step - loss: 0.9694 - accuracy: 0.7989 - val_loss: 0.6466 - val_accuracy: 0.7847
# Epoch 30/1000000
# 391/391 [==============================] - 57s 146ms/step - loss: 0.9803 - accuracy: 0.7970 - val_loss: 0.7643 - val_accuracy: 0.7549
# Epoch 31/1000000
# 391/391 [==============================] - 57s 147ms/step - loss: 0.9644 - accuracy: 0.8014 - val_loss: 0.5806 - val_accuracy: 0.8074
# Epoch 32/1000000
# 391/391 [==============================] - 57s 147ms/step - loss: 0.8292 - accuracy: 0.8439 - val_loss: 0.4141 - val_accuracy: 0.8628
# Epoch 33/1000000
# 391/391 [==============================] - 73s 187ms/step - loss: 0.6487 - accuracy: 0.6877 - val_loss: 0.3621 - val_accuracy: 0.8751
# Epoch 34/1000000
# 391/391 [==============================] - 91s 234ms/step - loss: 0.5648 - accuracy: 0.4388 - val_loss: 0.3570 - val_accuracy: 0.8835
# Epoch 35/1000000
# 391/391 [==============================] - 91s 233ms/step - loss: 0.5180 - accuracy: 0.4424 - val_loss: 0.3688 - val_accuracy: 0.8812
# Epoch 36/1000000
# 391/391 [==============================] - 91s 233ms/step - loss: 0.4780 - accuracy: 0.4456 - val_loss: 0.3412 - val_accuracy: 0.8885
# Epoch 37/1000000
# 391/391 [==============================] - 92s 234ms/step - loss: 0.4495 - accuracy: 0.4472 - val_loss: 0.3731 - val_accuracy: 0.8794
# Epoch 38/1000000
# 391/391 [==============================] - 91s 234ms/step - loss: 0.4359 - accuracy: 0.4430 - val_loss: 0.3429 - val_accuracy: 0.8863
# Epoch 39/1000000
# 391/391 [==============================] - 91s 234ms/step - loss: 0.4160 - accuracy: 0.4474 - val_loss: 0.3681 - val_accuracy: 0.8833
# Epoch 40/1000000
# 391/391 [==============================] - 91s 234ms/step - loss: 0.4150 - accuracy: 0.4412 - val_loss: 0.3587 - val_accuracy: 0.8803
# Epoch 41/1000000
# 391/391 [==============================] - 91s 234ms/step - loss: 0.4036 - accuracy: 0.4448 - val_loss: 0.3869 - val_accuracy: 0.8763
# Epoch 42/1000000
# 391/391 [==============================] - 92s 234ms/step - loss: 0.3985 - accuracy: 0.4443 - val_loss: 0.4236 - val_accuracy: 0.8663
# Epoch 43/1000000
# 391/391 [==============================] - 91s 234ms/step - loss: 0.3971 - accuracy: 0.4454 - val_loss: 0.3567 - val_accuracy: 0.8835
# Epoch 44/1000000
# 391/391 [==============================] - 92s 235ms/step - loss: 0.3705 - accuracy: 0.4691 - val_loss: 0.2997 - val_accuracy: 0.9057
# Epoch 45/1000000
# 391/391 [==============================] - 91s 234ms/step - loss: 0.2803 - accuracy: 0.5323 - val_loss: 0.3064 - val_accuracy: 0.9060
# Epoch 46/1000000
# 391/391 [==============================] - 92s 234ms/step - loss: 0.2601 - accuracy: 0.5468 - val_loss: 0.3191 - val_accuracy: 0.9077
# Epoch 47/1000000
# 391/391 [==============================] - 92s 235ms/step - loss: 0.2440 - accuracy: 0.5422 - val_loss: 0.3304 - val_accuracy: 0.9058
# Epoch 48/1000000
# 391/391 [==============================] - 91s 234ms/step - loss: 0.2314 - accuracy: 0.5576 - val_loss: 0.3278 - val_accuracy: 0.9099
# Epoch 49/1000000
# 391/391 [==============================] - 91s 233ms/step - loss: 0.2213 - accuracy: 0.5611 - val_loss: 0.3504 - val_accuracy: 0.9058
# Epoch 50/1000000
# 391/391 [==============================] - 92s 235ms/step - loss: 0.2123 - accuracy: 0.5642 - val_loss: 0.3533 - val_accuracy: 0.9092
# Epoch 51/1000000
# 391/391 [==============================] - 91s 233ms/step - loss: 0.2053 - accuracy: 0.5681 - val_loss: 0.3558 - val_accuracy: 0.9078
# Epoch 52/1000000
# 172/391 [============>.................] - ETA: 53s - loss: 0.1987 - accuracy: 0.5771 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00

# %%
# Test the model
x_test, y_test = dset.test_data[:]
eval_model(model, x_test, y_test)
# Out:
# 10000/10000 [==============================] - 3s 264us/step
# Test loss: 0.5321150021553039
# Test accuracy: 0.9062

# %%
# Save model, plots and history
save(model, history, 'res-net-28-2-1hr-nodropout-IS', True)

# %%
# Load model and draw plots 
path = "gdrive/My Drive/"
file_name = "res-net-28-2-1hr-nodropout-IS"
model = load_model(path + file_name + ".h5", custom_objects = {'LayerNormalization' : LayerNormalization})

# Display Saved plots
listOfImageNames = [path + file_name + "-acc.png",
                    path + file_name + "-loss.png"]

for imageName in listOfImageNames:
    display(Image(filename=imageName))
    
# Load history
history = np.load(path + file_name + "-history.npy")

# %% [markdown]
# ### Wide ResNet 28-2 without dropout and max time of 1 hr (without IS)

# %%
args = Args(depth = 28, width = 2, presample = 3.0, batch_size = 128, time_budget = 1, dropout = 0, useIS = False)
model, history = build_wide_res(args, dset)
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 32, 32, 16)   432         input_5[0][0]
# __________________________________________________________________________________________________
# layer_normalization_51 (LayerNo (None, 32, 32, 16)   17          conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 32, 32, 16)   0           layer_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 32, 32, 32)   4608        activation_53[0][0]
# __________________________________________________________________________________________________
# layer_normalization_52 (LayerNo (None, 32, 32, 32)   33          conv2d_58[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 32, 32, 32)   0           layer_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 32, 32, 32)   512         conv2d_57[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 32, 32, 32)   9216        activation_54[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, 32, 32, 32)   0           conv2d_60[0][0]
#                                                                  conv2d_59[0][0]
# __________________________________________________________________________________________________
# layer_normalization_53 (LayerNo (None, 32, 32, 32)   33          add_25[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 32, 32, 32)   0           layer_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 32, 32, 32)   9216        activation_55[0][0]
# __________________________________________________________________________________________________
# layer_normalization_54 (LayerNo (None, 32, 32, 32)   33          conv2d_61[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 32, 32, 32)   0           layer_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 32, 32, 32)   9216        activation_56[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, 32, 32, 32)   0           add_25[0][0]
#                                                                  conv2d_62[0][0]
# __________________________________________________________________________________________________
# layer_normalization_55 (LayerNo (None, 32, 32, 32)   33          add_26[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 32, 32, 32)   0           layer_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 32, 32, 32)   9216        activation_57[0][0]
# __________________________________________________________________________________________________
# layer_normalization_56 (LayerNo (None, 32, 32, 32)   33          conv2d_63[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 32, 32, 32)   0           layer_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 32, 32, 32)   9216        activation_58[0][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, 32, 32, 32)   0           add_26[0][0]
#                                                                  conv2d_64[0][0]
# __________________________________________________________________________________________________
# layer_normalization_57 (LayerNo (None, 32, 32, 32)   33          add_27[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 32, 32, 32)   0           layer_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 32, 32, 32)   9216        activation_59[0][0]
# __________________________________________________________________________________________________
# layer_normalization_58 (LayerNo (None, 32, 32, 32)   33          conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 32, 32, 32)   0           layer_normalization_58[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 32, 32, 32)   9216        activation_60[0][0]
# __________________________________________________________________________________________________
# add_28 (Add)                    (None, 32, 32, 32)   0           add_27[0][0]
#                                                                  conv2d_66[0][0]
# __________________________________________________________________________________________________
# layer_normalization_59 (LayerNo (None, 32, 32, 32)   33          add_28[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 32, 32, 32)   0           layer_normalization_59[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 16, 16, 64)   18432       activation_61[0][0]
# __________________________________________________________________________________________________
# layer_normalization_60 (LayerNo (None, 16, 16, 64)   65          conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 16, 16, 64)   0           layer_normalization_60[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 16, 16, 64)   2048        add_28[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 16, 16, 64)   36864       activation_62[0][0]
# __________________________________________________________________________________________________
# add_29 (Add)                    (None, 16, 16, 64)   0           conv2d_69[0][0]
#                                                                  conv2d_68[0][0]
# __________________________________________________________________________________________________
# layer_normalization_61 (LayerNo (None, 16, 16, 64)   65          add_29[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 16, 16, 64)   0           layer_normalization_61[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 16, 16, 64)   36864       activation_63[0][0]
# __________________________________________________________________________________________________
# layer_normalization_62 (LayerNo (None, 16, 16, 64)   65          conv2d_70[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 16, 16, 64)   0           layer_normalization_62[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 16, 16, 64)   36864       activation_64[0][0]
# __________________________________________________________________________________________________
# add_30 (Add)                    (None, 16, 16, 64)   0           add_29[0][0]
#                                                                  conv2d_71[0][0]
# __________________________________________________________________________________________________
# layer_normalization_63 (LayerNo (None, 16, 16, 64)   65          add_30[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 16, 16, 64)   0           layer_normalization_63[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 16, 16, 64)   36864       activation_65[0][0]
# __________________________________________________________________________________________________
# layer_normalization_64 (LayerNo (None, 16, 16, 64)   65          conv2d_72[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 16, 16, 64)   0           layer_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 16, 16, 64)   36864       activation_66[0][0]
# __________________________________________________________________________________________________
# add_31 (Add)                    (None, 16, 16, 64)   0           add_30[0][0]
#                                                                  conv2d_73[0][0]
# __________________________________________________________________________________________________
# layer_normalization_65 (LayerNo (None, 16, 16, 64)   65          add_31[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 16, 16, 64)   0           layer_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 16, 16, 64)   36864       activation_67[0][0]
# __________________________________________________________________________________________________
# layer_normalization_66 (LayerNo (None, 16, 16, 64)   65          conv2d_74[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 16, 16, 64)   0           layer_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 16, 16, 64)   36864       activation_68[0][0]
# __________________________________________________________________________________________________
# add_32 (Add)                    (None, 16, 16, 64)   0           add_31[0][0]
#                                                                  conv2d_75[0][0]
# __________________________________________________________________________________________________
# layer_normalization_67 (LayerNo (None, 16, 16, 64)   65          add_32[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 16, 16, 64)   0           layer_normalization_67[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 8, 8, 128)    73728       activation_69[0][0]
# __________________________________________________________________________________________________
# layer_normalization_68 (LayerNo (None, 8, 8, 128)    129         conv2d_76[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 8, 8, 128)    0           layer_normalization_68[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 8, 8, 128)    8192        add_32[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 8, 8, 128)    147456      activation_70[0][0]
# __________________________________________________________________________________________________
# add_33 (Add)                    (None, 8, 8, 128)    0           conv2d_78[0][0]
#                                                                  conv2d_77[0][0]
# __________________________________________________________________________________________________
# layer_normalization_69 (LayerNo (None, 8, 8, 128)    129         add_33[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 8, 8, 128)    0           layer_normalization_69[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 8, 8, 128)    147456      activation_71[0][0]
# __________________________________________________________________________________________________
# layer_normalization_70 (LayerNo (None, 8, 8, 128)    129         conv2d_79[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 8, 8, 128)    0           layer_normalization_70[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 8, 8, 128)    147456      activation_72[0][0]
# __________________________________________________________________________________________________
# add_34 (Add)                    (None, 8, 8, 128)    0           add_33[0][0]
#                                                                  conv2d_80[0][0]
# __________________________________________________________________________________________________
# layer_normalization_71 (LayerNo (None, 8, 8, 128)    129         add_34[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, 8, 8, 128)    0           layer_normalization_71[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 8, 8, 128)    147456      activation_73[0][0]
# __________________________________________________________________________________________________
# layer_normalization_72 (LayerNo (None, 8, 8, 128)    129         conv2d_81[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 8, 8, 128)    0           layer_normalization_72[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 8, 8, 128)    147456      activation_74[0][0]
# __________________________________________________________________________________________________
# add_35 (Add)                    (None, 8, 8, 128)    0           add_34[0][0]
#                                                                  conv2d_82[0][0]
# __________________________________________________________________________________________________
# layer_normalization_73 (LayerNo (None, 8, 8, 128)    129         add_35[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 8, 8, 128)    0           layer_normalization_73[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 8, 8, 128)    147456      activation_75[0][0]
# __________________________________________________________________________________________________
# layer_normalization_74 (LayerNo (None, 8, 8, 128)    129         conv2d_83[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 8, 8, 128)    0           layer_normalization_74[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 8, 8, 128)    147456      activation_76[0][0]
# __________________________________________________________________________________________________
# add_36 (Add)                    (None, 8, 8, 128)    0           add_35[0][0]
#                                                                  conv2d_84[0][0]
# __________________________________________________________________________________________________
# layer_normalization_75 (LayerNo (None, 8, 8, 128)    129         add_36[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 8, 8, 128)    0           layer_normalization_75[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_3 (Glo (None, 128)          0           activation_77[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 10)           1290        global_average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 10)           0           dense_3[0][0]
# ==================================================================================================
# Total params: 1,465,827
# Trainable params: 1,465,827
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/1000000
# 391/391 [==============================] - 60s 154ms/step - loss: 2.8292 - acc: 0.1591 - val_loss: 2.4225 - val_acc: 0.2188
# Epoch 2/1000000
# 391/391 [==============================] - 57s 145ms/step - loss: 2.2048 - acc: 0.2639 - val_loss: 2.0460 - val_acc: 0.2980
# Epoch 3/1000000
# 391/391 [==============================] - 57s 145ms/step - loss: 1.8541 - acc: 0.3756 - val_loss: 1.7500 - val_acc: 0.4084
# Epoch 4/1000000
# 391/391 [==============================] - 57s 145ms/step - loss: 1.6300 - acc: 0.4627 - val_loss: 1.4552 - val_acc: 0.5348
# Epoch 5/1000000
# 391/391 [==============================] - 57s 145ms/step - loss: 1.4914 - acc: 0.5200 - val_loss: 1.4717 - val_acc: 0.5237
# Epoch 6/1000000
# 391/391 [==============================] - 57s 145ms/step - loss: 1.4092 - acc: 0.5578 - val_loss: 1.3908 - val_acc: 0.5813
# Epoch 7/1000000
# 391/391 [==============================] - 57s 145ms/step - loss: 1.3088 - acc: 0.6004 - val_loss: 1.5838 - val_acc: 0.5360
# Epoch 8/1000000
# 391/391 [==============================] - 57s 145ms/step - loss: 1.2660 - acc: 0.6238 - val_loss: 1.3829 - val_acc: 0.5793
# Epoch 9/1000000
# 391/391 [==============================] - 56s 144ms/step - loss: 1.2344 - acc: 0.6407 - val_loss: 1.2179 - val_acc: 0.6513
# Epoch 10/1000000
# 391/391 [==============================] - 56s 144ms/step - loss: 1.2004 - acc: 0.6606 - val_loss: 1.1523 - val_acc: 0.6756
# Epoch 11/1000000
# 391/391 [==============================] - 56s 144ms/step - loss: 1.1462 - acc: 0.6824 - val_loss: 1.2884 - val_acc: 0.6315
# Epoch 12/1000000
# 391/391 [==============================] - 56s 144ms/step - loss: 1.1250 - acc: 0.6975 - val_loss: 1.0833 - val_acc: 0.7152
# Epoch 13/1000000
# 391/391 [==============================] - 56s 144ms/step - loss: 1.0847 - acc: 0.7196 - val_loss: 1.1056 - val_acc: 0.7119
# Epoch 14/1000000
# 391/391 [==============================] - 57s 145ms/step - loss: 1.0706 - acc: 0.7288 - val_loss: 1.0996 - val_acc: 0.7213
# Epoch 15/1000000
# 391/391 [==============================] - 56s 144ms/step - loss: 1.0496 - acc: 0.7425 - val_loss: 1.1056 - val_acc: 0.7222
# Epoch 16/1000000
# 391/391 [==============================] - 56s 144ms/step - loss: 1.0306 - acc: 0.7528 - val_loss: 1.0389 - val_acc: 0.7525
# Epoch 17/1000000
# 391/391 [==============================] - 56s 144ms/step - loss: 1.0173 - acc: 0.7616 - val_loss: 1.0820 - val_acc: 0.7461
# Epoch 18/1000000
# 391/391 [==============================] - 56s 144ms/step - loss: 1.0056 - acc: 0.7699 - val_loss: 1.0465 - val_acc: 0.7507
# Epoch 19/1000000
# 391/391 [==============================] - 57s 147ms/step - loss: 0.9975 - acc: 0.7704 - val_loss: 1.0457 - val_acc: 0.7532
# Epoch 20/1000000
# 391/391 [==============================] - 57s 146ms/step - loss: 0.9974 - acc: 0.7737 - val_loss: 0.9835 - val_acc: 0.7765
# Epoch 21/1000000
# 391/391 [==============================] - 57s 146ms/step - loss: 0.9764 - acc: 0.7827 - val_loss: 1.0802 - val_acc: 0.7493
# Epoch 22/1000000
# 391/391 [==============================] - 57s 145ms/step - loss: 0.9861 - acc: 0.7821 - val_loss: 0.9475 - val_acc: 0.7945
# Epoch 23/1000000
# 391/391 [==============================] - 57s 145ms/step - loss: 0.9750 - acc: 0.7870 - val_loss: 0.8961 - val_acc: 0.8157
# Epoch 24/1000000
# 391/391 [==============================] - 57s 146ms/step - loss: 0.9935 - acc: 0.7822 - val_loss: 1.1501 - val_acc: 0.7384
# Epoch 25/1000000
# 391/391 [==============================] - 57s 145ms/step - loss: 0.9714 - acc: 0.7924 - val_loss: 0.9984 - val_acc: 0.7861
# Epoch 26/1000000
# 391/391 [==============================] - 57s 145ms/step - loss: 0.9742 - acc: 0.7908 - val_loss: 0.9916 - val_acc: 0.7854
# Epoch 27/1000000
# 391/391 [==============================] - 56s 144ms/step - loss: 0.9726 - acc: 0.7921 - val_loss: 1.0225 - val_acc: 0.7791
# Epoch 28/1000000
# 391/391 [==============================] - 56s 144ms/step - loss: 0.9595 - acc: 0.7960 - val_loss: 1.0467 - val_acc: 0.7664
# Epoch 29/1000000
# 391/391 [==============================] - 56s 144ms/step - loss: 0.9787 - acc: 0.7941 - val_loss: 0.9869 - val_acc: 0.7877
# Epoch 30/1000000
# 391/391 [==============================] - 56s 144ms/step - loss: 0.9597 - acc: 0.7978 - val_loss: 1.0572 - val_acc: 0.7769
# Epoch 31/1000000
# 391/391 [==============================] - 56s 144ms/step - loss: 0.9545 - acc: 0.8015 - val_loss: 0.9739 - val_acc: 0.7994
# Epoch 32/1000000
# 391/391 [==============================] - 56s 144ms/step - loss: 0.9110 - acc: 0.8168 - val_loss: 0.8018 - val_acc: 0.8528
# Epoch 33/1000000
# 391/391 [==============================] - 56s 144ms/step - loss: 0.6981 - acc: 0.8765 - val_loss: 0.7233 - val_acc: 0.8616
# Epoch 34/1000000
# 391/391 [==============================] - 56s 144ms/step - loss: 0.6318 - acc: 0.8870 - val_loss: 0.7177 - val_acc: 0.8546
# Epoch 35/1000000
# 391/391 [==============================] - 56s 144ms/step - loss: 0.6027 - acc: 0.8868 - val_loss: 0.6542 - val_acc: 0.8686
# Epoch 36/1000000
# 391/391 [==============================] - 56s 144ms/step - loss: 0.5699 - acc: 0.8912 - val_loss: 0.6243 - val_acc: 0.8732
# Epoch 37/1000000
# 391/391 [==============================] - 56s 144ms/step - loss: 0.5572 - acc: 0.8913 - val_loss: 0.6446 - val_acc: 0.8635
# Epoch 38/1000000
# 391/391 [==============================] - 56s 144ms/step - loss: 0.5462 - acc: 0.8913 - val_loss: 0.6116 - val_acc: 0.8698
# Epoch 39/1000000
# 391/391 [==============================] - 56s 143ms/step - loss: 0.5360 - acc: 0.8922 - val_loss: 0.6066 - val_acc: 0.8691
# Epoch 40/1000000
# 391/391 [==============================] - 58s 148ms/step - loss: 0.5280 - acc: 0.8944 - val_loss: 0.6297 - val_acc: 0.8657
# Epoch 41/1000000
# 391/391 [==============================] - 57s 145ms/step - loss: 0.5284 - acc: 0.8924 - val_loss: 0.6331 - val_acc: 0.8609
# Epoch 42/1000000
# 391/391 [==============================] - 57s 145ms/step - loss: 0.5267 - acc: 0.8931 - val_loss: 0.6190 - val_acc: 0.8640
# Epoch 43/1000000
# 391/391 [==============================] - 57s 145ms/step - loss: 0.5282 - acc: 0.8927 - val_loss: 0.6320 - val_acc: 0.8639
# Epoch 44/1000000
# 391/391 [==============================] - 57s 145ms/step - loss: 0.5252 - acc: 0.8949 - val_loss: 0.6777 - val_acc: 0.8472
# Epoch 45/1000000
# 391/391 [==============================] - 57s 145ms/step - loss: 0.5251 - acc: 0.8945 - val_loss: 0.6059 - val_acc: 0.8706
# Epoch 46/1000000
# 391/391 [==============================] - 57s 145ms/step - loss: 0.5231 - acc: 0.8965 - val_loss: 0.6783 - val_acc: 0.8558
# Epoch 47/1000000
# 391/391 [==============================] - 57s 146ms/step - loss: 0.5195 - acc: 0.8982 - val_loss: 0.6478 - val_acc: 0.8642
# Epoch 48/1000000
# 391/391 [==============================] - 57s 146ms/step - loss: 0.5254 - acc: 0.8977 - val_loss: 0.5969 - val_acc: 0.8750
# Epoch 49/1000000
# 391/391 [==============================] - 57s 145ms/step - loss: 0.5154 - acc: 0.9010 - val_loss: 0.6030 - val_acc: 0.8751
# Epoch 50/1000000
# 391/391 [==============================] - 57s 146ms/step - loss: 0.5176 - acc: 0.9020 - val_loss: 0.5860 - val_acc: 0.8849
# Epoch 51/1000000
# 391/391 [==============================] - 57s 146ms/step - loss: 0.5105 - acc: 0.9030 - val_loss: 0.5614 - val_acc: 0.8927
# Epoch 52/1000000
# 391/391 [==============================] - 57s 146ms/step - loss: 0.3960 - acc: 0.9437 - val_loss: 0.5402 - val_acc: 0.9010
# Epoch 53/1000000
# 391/391 [==============================] - 57s 145ms/step - loss: 0.3651 - acc: 0.9517 - val_loss: 0.5208 - val_acc: 0.9085
# Epoch 54/1000000
# 391/391 [==============================] - 57s 145ms/step - loss: 0.3520 - acc: 0.9535 - val_loss: 0.5152 - val_acc: 0.9088
# Epoch 55/1000000
# 391/391 [==============================] - 57s 146ms/step - loss: 0.3359 - acc: 0.9580 - val_loss: 0.5297 - val_acc: 0.9037
# Epoch 56/1000000
# 391/391 [==============================] - 57s 145ms/step - loss: 0.3252 - acc: 0.9594 - val_loss: 0.5241 - val_acc: 0.9061
# Epoch 57/1000000
# 391/391 [==============================] - 57s 146ms/step - loss: 0.3179 - acc: 0.9598 - val_loss: 0.5134 - val_acc: 0.9079
# Epoch 58/1000000
# 391/391 [==============================] - 57s 146ms/step - loss: 0.3072 - acc: 0.9624 - val_loss: 0.5010 - val_acc: 0.9090
# Epoch 59/1000000
# 391/391 [==============================] - 57s 145ms/step - loss: 0.2995 - acc: 0.9644 - val_loss: 0.5156 - val_acc: 0.9058
# Epoch 60/1000000
# 391/391 [==============================] - 57s 145ms/step - loss: 0.2919 - acc: 0.9650 - val_loss: 0.5128 - val_acc: 0.9045
# Epoch 61/1000000
# 391/391 [==============================] - 57s 146ms/step - loss: 0.2863 - acc: 0.9658 - val_loss: 0.5339 - val_acc: 0.9008
# Epoch 62/1000000
# 391/391 [==============================] - 57s 146ms/step - loss: 0.2808 - acc: 0.9658 - val_loss: 0.5387 - val_acc: 0.9004
# Epoch 63/1000000
# 391/391 [==============================] - 57s 146ms/step - loss: 0.2789 - acc: 0.9659 - val_loss: 0.5098 - val_acc: 0.9062
# Epoch 64/1000000
# 167/391 [===========>..................] - ETA: 31s - loss: 0.2674 - acc: 0.9690

# %%
# Test the model
x_test, y_test = dset.test_data[:]
eval_model(model, x_test, y_test)
# Out:
# 10000/10000 [==============================] - 3s 256us/step
# Test loss: 0.5064974669933319
# Test accuracy: 0.9089

# %%
# Save model, plots and history
save(model, history, 'res-net-28-2-1hr-nodropout-noIS', False)

# %%
# Load model and draw plots 
path = "gdrive/My Drive/"
file_name = "res-net-28-2-1hr-nodropout-noIS"
model = load_model(path + file_name + ".h5", custom_objects = {'LayerNormalization' : LayerNormalization})

# Display Saved plots
listOfImageNames = [path + file_name + "-acc.png",
                    path + file_name + "-loss.png"]

for imageName in listOfImageNames:
    display(Image(filename=imageName))
    
# Load history
history = np.load(path + file_name + "-history.npy")

# %% [markdown]
# # Models for Embeddings

# %%
args = Args(depth = 28, width = 2, presample = 3.0, batch_size = 128, time_budget = 1, dropout = 0, useIS = False)
model, history = build_wide_res(args, dset)
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 32, 32, 16)   432         input_4[0][0]
# __________________________________________________________________________________________________
# layer_normalization_26 (LayerNo (None, 32, 32, 16)   17          conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 32, 32, 16)   0           layer_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 32, 32, 32)   4608        activation_27[0][0]
# __________________________________________________________________________________________________
# layer_normalization_27 (LayerNo (None, 32, 32, 32)   33          conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 32, 32, 32)   0           layer_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 32, 32, 32)   512         conv2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 32, 32, 32)   9216        activation_28[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 32, 32, 32)   0           conv2d_32[0][0]
#                                                                  conv2d_31[0][0]
# __________________________________________________________________________________________________
# layer_normalization_28 (LayerNo (None, 32, 32, 32)   33          add_13[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 32, 32, 32)   0           layer_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 32, 32, 32)   9216        activation_29[0][0]
# __________________________________________________________________________________________________
# layer_normalization_29 (LayerNo (None, 32, 32, 32)   33          conv2d_33[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 32, 32, 32)   0           layer_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 32, 32, 32)   9216        activation_30[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 32, 32, 32)   0           add_13[0][0]
#                                                                  conv2d_34[0][0]
# __________________________________________________________________________________________________
# layer_normalization_30 (LayerNo (None, 32, 32, 32)   33          add_14[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 32, 32, 32)   0           layer_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 32, 32, 32)   9216        activation_31[0][0]
# __________________________________________________________________________________________________
# layer_normalization_31 (LayerNo (None, 32, 32, 32)   33          conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 32, 32, 32)   0           layer_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 32, 32, 32)   9216        activation_32[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 32, 32, 32)   0           add_14[0][0]
#                                                                  conv2d_36[0][0]
# __________________________________________________________________________________________________
# layer_normalization_32 (LayerNo (None, 32, 32, 32)   33          add_15[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 32, 32, 32)   0           layer_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 32, 32, 32)   9216        activation_33[0][0]
# __________________________________________________________________________________________________
# layer_normalization_33 (LayerNo (None, 32, 32, 32)   33          conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 32, 32, 32)   0           layer_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 32, 32, 32)   9216        activation_34[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 32, 32, 32)   0           add_15[0][0]
#                                                                  conv2d_38[0][0]
# __________________________________________________________________________________________________
# layer_normalization_34 (LayerNo (None, 32, 32, 32)   33          add_16[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 32, 32, 32)   0           layer_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 16, 16, 64)   18432       activation_35[0][0]
# __________________________________________________________________________________________________
# layer_normalization_35 (LayerNo (None, 16, 16, 64)   65          conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 16, 16, 64)   0           layer_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 16, 16, 64)   2048        add_16[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 16, 16, 64)   36864       activation_36[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 16, 16, 64)   0           conv2d_41[0][0]
#                                                                  conv2d_40[0][0]
# __________________________________________________________________________________________________
# layer_normalization_36 (LayerNo (None, 16, 16, 64)   65          add_17[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 16, 16, 64)   0           layer_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 16, 16, 64)   36864       activation_37[0][0]
# __________________________________________________________________________________________________
# layer_normalization_37 (LayerNo (None, 16, 16, 64)   65          conv2d_42[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 16, 16, 64)   0           layer_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 16, 16, 64)   36864       activation_38[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 16, 16, 64)   0           add_17[0][0]
#                                                                  conv2d_43[0][0]
# __________________________________________________________________________________________________
# layer_normalization_38 (LayerNo (None, 16, 16, 64)   65          add_18[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 16, 16, 64)   0           layer_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 16, 16, 64)   36864       activation_39[0][0]
# __________________________________________________________________________________________________
# layer_normalization_39 (LayerNo (None, 16, 16, 64)   65          conv2d_44[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 16, 16, 64)   0           layer_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 16, 16, 64)   36864       activation_40[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 16, 16, 64)   0           add_18[0][0]
#                                                                  conv2d_45[0][0]
# __________________________________________________________________________________________________
# layer_normalization_40 (LayerNo (None, 16, 16, 64)   65          add_19[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 16, 16, 64)   0           layer_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 16, 16, 64)   36864       activation_41[0][0]
# __________________________________________________________________________________________________
# layer_normalization_41 (LayerNo (None, 16, 16, 64)   65          conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 16, 16, 64)   0           layer_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 16, 16, 64)   36864       activation_42[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 16, 16, 64)   0           add_19[0][0]
#                                                                  conv2d_47[0][0]
# __________________________________________________________________________________________________
# layer_normalization_42 (LayerNo (None, 16, 16, 64)   65          add_20[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 16, 16, 64)   0           layer_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 8, 8, 128)    73728       activation_43[0][0]
# __________________________________________________________________________________________________
# layer_normalization_43 (LayerNo (None, 8, 8, 128)    129         conv2d_48[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 8, 8, 128)    0           layer_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 8, 8, 128)    8192        add_20[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 8, 8, 128)    147456      activation_44[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 8, 8, 128)    0           conv2d_50[0][0]
#                                                                  conv2d_49[0][0]
# __________________________________________________________________________________________________
# layer_normalization_44 (LayerNo (None, 8, 8, 128)    129         add_21[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 8, 8, 128)    0           layer_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 8, 8, 128)    147456      activation_45[0][0]
# __________________________________________________________________________________________________
# layer_normalization_45 (LayerNo (None, 8, 8, 128)    129         conv2d_51[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 8, 8, 128)    0           layer_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 8, 8, 128)    147456      activation_46[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 8, 8, 128)    0           add_21[0][0]
#                                                                  conv2d_52[0][0]
# __________________________________________________________________________________________________
# layer_normalization_46 (LayerNo (None, 8, 8, 128)    129         add_22[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 8, 8, 128)    0           layer_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 8, 8, 128)    147456      activation_47[0][0]
# __________________________________________________________________________________________________
# layer_normalization_47 (LayerNo (None, 8, 8, 128)    129         conv2d_53[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 8, 8, 128)    0           layer_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 8, 8, 128)    147456      activation_48[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 8, 8, 128)    0           add_22[0][0]
#                                                                  conv2d_54[0][0]
# __________________________________________________________________________________________________
# layer_normalization_48 (LayerNo (None, 8, 8, 128)    129         add_23[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 8, 8, 128)    0           layer_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 8, 8, 128)    147456      activation_49[0][0]
# __________________________________________________________________________________________________
# layer_normalization_49 (LayerNo (None, 8, 8, 128)    129         conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 8, 8, 128)    0           layer_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 8, 8, 128)    147456      activation_50[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 8, 8, 128)    0           add_23[0][0]
#                                                                  conv2d_56[0][0]
# __________________________________________________________________________________________________
# layer_normalization_50 (LayerNo (None, 8, 8, 128)    129         add_24[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 8, 8, 128)    0           layer_normalization_50[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 128)          0           activation_51[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 10)           1290        global_average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 10)           0           dense_2[0][0]
# ==================================================================================================
# Total params: 1,465,827
# Trainable params: 1,465,827
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/1000000
# 391/391 [==============================] - 61s 155ms/step - loss: 2.9564 - acc: 0.1005 - val_loss: 2.7279 - val_acc: 0.1000
# Epoch 2/1000000
# 391/391 [==============================] - 56s 144ms/step - loss: 2.5156 - acc: 0.1474 - val_loss: 2.1745 - val_acc: 0.2322
# Epoch 3/1000000
# 391/391 [==============================] - 57s 145ms/step - loss: 2.0489 - acc: 0.2665 - val_loss: 1.9981 - val_acc: 0.3007
# Epoch 4/1000000
#  37/391 [=>............................] - ETA: 49s - loss: 1.9152 - acc: 0.3231

# %%
D = CIFAR10()

# %%
a,b = D.train_data[:]

# %%
a[0]
# Out:
# array([[[0.23137255, 0.24313726, 0.24705882],
#         [0.16862746, 0.18039216, 0.1764706 ],
#         [0.19607843, 0.1882353 , 0.16862746],
#         ...,
#         [0.61960787, 0.5176471 , 0.42352942],
#         [0.59607846, 0.49019608, 0.4       ],
#         [0.5803922 , 0.4862745 , 0.40392157]],
#
#        [[0.0627451 , 0.07843138, 0.07843138],
#         [0.        , 0.        , 0.        ],
#         [0.07058824, 0.03137255, 0.        ],
#         ...,
#         [0.48235294, 0.34509805, 0.21568628],
#         [0.46666667, 0.3254902 , 0.19607843],
#         [0.47843137, 0.34117648, 0.22352941]],
#
#        [[0.09803922, 0.09411765, 0.08235294],
#         [0.0627451 , 0.02745098, 0.        ],
#         [0.19215687, 0.10588235, 0.03137255],
#         ...,
#         [0.4627451 , 0.32941177, 0.19607843],
#         [0.47058824, 0.32941177, 0.19607843],
#         [0.42745098, 0.28627452, 0.16470589]],
#
#        ...,
#
#        [[0.8156863 , 0.6666667 , 0.3764706 ],
#         [0.7882353 , 0.6       , 0.13333334],
#         [0.7764706 , 0.6313726 , 0.10196079],
#         ...,
#         [0.627451  , 0.52156866, 0.27450982],
#         [0.21960784, 0.12156863, 0.02745098],
#         [0.20784314, 0.13333334, 0.07843138]],
#
#        [[0.7058824 , 0.54509807, 0.3764706 ],
#         [0.6784314 , 0.48235294, 0.16470589],
#         [0.7294118 , 0.5647059 , 0.11764706],
#         ...,
#         [0.72156864, 0.5803922 , 0.36862746],
#         [0.38039216, 0.24313726, 0.13333334],
#         [0.3254902 , 0.20784314, 0.13333334]],
#
#        [[0.69411767, 0.5647059 , 0.45490196],
#         [0.65882355, 0.5058824 , 0.36862746],
#         [0.7019608 , 0.5568628 , 0.34117648],
#         ...,
#         [0.84705883, 0.72156864, 0.54901963],
#         [0.5921569 , 0.4627451 , 0.32941177],
#         [0.48235294, 0.36078432, 0.28235295]]], dtype=float32)

# %% [markdown]
# ## Super Res model

# %%
from importance_sampling.datasets import InMemoryImageDataset
from keras.datasets import cifar10
from functools import partial

# Load dataset
x_t = np.load('gdrive/My Drive/upsampled_cifar10/x_train.npy')
y_t = np.load('gdrive/My Drive/upsampled_cifar10/y_train.npy')

c = cifar10
c.x_train = x_t
c.y_train = y_t

CIFAR10 = partial(InMemoryImageDataset.from_loadable, c)
ds_super_res = ZCAWhitening(CIFAR10())
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 19s 0us/step

# %% [markdown]
# ### Wide ResNet (28-2) with dropout and IS for max time of 1 hr on the output of ESRGAN (8x8 -> 32x32)

# %%
args = Args(depth = 28, width = 2, presample = 3.0, batch_size = 128, time_budget = 1, dropout = 0.3, useIS = True)
model, history = build_wide_res(args, ds_super_res)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 16)   432         input_1[0][0]
# __________________________________________________________________________________________________
# layer_normalization_1 (LayerNor (None, 32, 32, 16)   17          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 16)   0           layer_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 32)   4608        activation_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 32, 32, 32)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# layer_normalization_2 (LayerNor (None, 32, 32, 32)   33          dropout_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 32)   0           layer_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 32)   512         conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 32)   9216        activation_2[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 32)   0           conv2d_4[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# layer_normalization_3 (LayerNor (None, 32, 32, 32)   33          add_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 32)   0           layer_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 32)   9216        activation_3[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 32, 32, 32)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# layer_normalization_4 (LayerNor (None, 32, 32, 32)   33          dropout_2[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 32)   0           layer_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 32)   9216        activation_4[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 32, 32, 32)   0           add_1[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# layer_normalization_5 (LayerNor (None, 32, 32, 32)   33          add_2[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 32)   0           layer_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 32)   9216        activation_5[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 32, 32, 32)   0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# layer_normalization_6 (LayerNor (None, 32, 32, 32)   33          dropout_3[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 32)   0           layer_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 32)   9216        activation_6[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 32, 32, 32)   0           add_2[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# layer_normalization_7 (LayerNor (None, 32, 32, 32)   33          add_3[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 32, 32, 32)   0           layer_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 32)   9216        activation_7[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 32, 32, 32)   0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# layer_normalization_8 (LayerNor (None, 32, 32, 32)   33          dropout_4[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 32, 32, 32)   0           layer_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 32)   9216        activation_8[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 32, 32, 32)   0           add_3[0][0]
#                                                                  conv2d_10[0][0]
# __________________________________________________________________________________________________
# layer_normalization_9 (LayerNor (None, 32, 32, 32)   33          add_4[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 32, 32, 32)   0           layer_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 64)   18432       activation_9[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 16, 16, 64)   0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# layer_normalization_10 (LayerNo (None, 16, 16, 64)   65          dropout_5[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 16, 16, 64)   0           layer_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 64)   2048        add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 64)   36864       activation_10[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 16, 16, 64)   0           conv2d_13[0][0]
#                                                                  conv2d_12[0][0]
# __________________________________________________________________________________________________
# layer_normalization_11 (LayerNo (None, 16, 16, 64)   65          add_5[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 16, 16, 64)   0           layer_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 16, 16, 64)   36864       activation_11[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 16, 16, 64)   0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# layer_normalization_12 (LayerNo (None, 16, 16, 64)   65          dropout_6[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 16, 16, 64)   0           layer_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 16, 16, 64)   36864       activation_12[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 16, 16, 64)   0           add_5[0][0]
#                                                                  conv2d_15[0][0]
# __________________________________________________________________________________________________
# layer_normalization_13 (LayerNo (None, 16, 16, 64)   65          add_6[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 16, 16, 64)   0           layer_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 16, 16, 64)   36864       activation_13[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 16, 16, 64)   0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# layer_normalization_14 (LayerNo (None, 16, 16, 64)   65          dropout_7[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 16, 16, 64)   0           layer_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 16, 16, 64)   36864       activation_14[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 16, 16, 64)   0           add_6[0][0]
#                                                                  conv2d_17[0][0]
# __________________________________________________________________________________________________
# layer_normalization_15 (LayerNo (None, 16, 16, 64)   65          add_7[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 16, 16, 64)   0           layer_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 16, 16, 64)   36864       activation_15[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 16, 16, 64)   0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# layer_normalization_16 (LayerNo (None, 16, 16, 64)   65          dropout_8[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 16, 16, 64)   0           layer_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 16, 16, 64)   36864       activation_16[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 16, 16, 64)   0           add_7[0][0]
#                                                                  conv2d_19[0][0]
# __________________________________________________________________________________________________
# layer_normalization_17 (LayerNo (None, 16, 16, 64)   65          add_8[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 16, 16, 64)   0           layer_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 8, 8, 128)    73728       activation_17[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 8, 8, 128)    0           conv2d_20[0][0]
# __________________________________________________________________________________________________
# layer_normalization_18 (LayerNo (None, 8, 8, 128)    129         dropout_9[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 8, 8, 128)    0           layer_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 8, 8, 128)    8192        add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 8, 8, 128)    147456      activation_18[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 8, 8, 128)    0           conv2d_22[0][0]
#                                                                  conv2d_21[0][0]
# __________________________________________________________________________________________________
# layer_normalization_19 (LayerNo (None, 8, 8, 128)    129         add_9[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 8, 8, 128)    0           layer_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 8, 8, 128)    147456      activation_19[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 8, 8, 128)    0           conv2d_23[0][0]
# __________________________________________________________________________________________________
# layer_normalization_20 (LayerNo (None, 8, 8, 128)    129         dropout_10[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 8, 8, 128)    0           layer_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 8, 8, 128)    147456      activation_20[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 8, 8, 128)    0           add_9[0][0]
#                                                                  conv2d_24[0][0]
# __________________________________________________________________________________________________
# layer_normalization_21 (LayerNo (None, 8, 8, 128)    129         add_10[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 8, 8, 128)    0           layer_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 8, 8, 128)    147456      activation_21[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 8, 8, 128)    0           conv2d_25[0][0]
# __________________________________________________________________________________________________
# layer_normalization_22 (LayerNo (None, 8, 8, 128)    129         dropout_11[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 8, 8, 128)    0           layer_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 8, 8, 128)    147456      activation_22[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 8, 8, 128)    0           add_10[0][0]
#                                                                  conv2d_26[0][0]
# __________________________________________________________________________________________________
# layer_normalization_23 (LayerNo (None, 8, 8, 128)    129         add_11[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 8, 8, 128)    0           layer_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 8, 8, 128)    147456      activation_23[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 8, 8, 128)    0           conv2d_27[0][0]
# __________________________________________________________________________________________________
# layer_normalization_24 (LayerNo (None, 8, 8, 128)    129         dropout_12[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 8, 8, 128)    0           layer_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 8, 8, 128)    147456      activation_24[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 8, 8, 128)    0           add_11[0][0]
#                                                                  conv2d_28[0][0]
# __________________________________________________________________________________________________
# layer_normalization_25 (LayerNo (None, 8, 8, 128)    129         add_12[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 8, 8, 128)    0           layer_normalization_25[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 128)          0           activation_25[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 10)           1290        global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 10)           0           dense_1[0][0]
# ==================================================================================================
# Total params: 1,465,827
# Trainable params: 1,465,827
# Non-trainable params: 0
# __________________________________________________________________________________________________
# [NOTICE]: You are using BatchNormalization and/or Dropout.
# Those layers may affect the importance calculations and you are advised to exchange them for LayerNormalization or BatchNormalization in test mode and L2 regularization.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/1000000
# 391/391 [==============================] - 69s 177ms/step - loss: 2.9310 - accuracy: 0.1007 - val_loss: 2.3006 - val_accuracy: 0.1098
# Epoch 2/1000000
# 391/391 [==============================] - 63s 161ms/step - loss: 2.4551 - accuracy: 0.1711 - val_loss: 1.8412 - val_accuracy: 0.2789
# Epoch 3/1000000
# 391/391 [==============================] - 63s 161ms/step - loss: 1.9681 - accuracy: 0.3139 - val_loss: 1.8477 - val_accuracy: 0.3284
# Epoch 4/1000000
# 391/391 [==============================] - 63s 161ms/step - loss: 1.7345 - accuracy: 0.4077 - val_loss: 1.4941 - val_accuracy: 0.4474
# Epoch 5/1000000
# 391/391 [==============================] - 63s 161ms/step - loss: 1.5904 - accuracy: 0.4675 - val_loss: 1.3147 - val_accuracy: 0.5202
# Epoch 6/1000000
# 391/391 [==============================] - 63s 161ms/step - loss: 1.4839 - accuracy: 0.5200 - val_loss: 1.2242 - val_accuracy: 0.5557
# Epoch 7/1000000
# 391/391 [==============================] - 63s 162ms/step - loss: 1.3924 - accuracy: 0.5661 - val_loss: 1.2846 - val_accuracy: 0.5349
# Epoch 8/1000000
# 391/391 [==============================] - 63s 161ms/step - loss: 1.3227 - accuracy: 0.6025 - val_loss: 1.1006 - val_accuracy: 0.6155
# Epoch 9/1000000
# 391/391 [==============================] - 63s 161ms/step - loss: 1.2868 - accuracy: 0.6209 - val_loss: 1.0476 - val_accuracy: 0.6353
# Epoch 10/1000000
# 391/391 [==============================] - 63s 160ms/step - loss: 1.2584 - accuracy: 0.6358 - val_loss: 1.0809 - val_accuracy: 0.6292
# Epoch 11/1000000
# 391/391 [==============================] - 63s 161ms/step - loss: 1.2374 - accuracy: 0.6496 - val_loss: 0.9308 - val_accuracy: 0.6702
# Epoch 12/1000000
# 391/391 [==============================] - 63s 161ms/step - loss: 1.2003 - accuracy: 0.6706 - val_loss: 0.8197 - val_accuracy: 0.7121
# Epoch 13/1000000
# 391/391 [==============================] - 63s 162ms/step - loss: 1.1786 - accuracy: 0.6814 - val_loss: 0.8603 - val_accuracy: 0.6929
# Epoch 14/1000000
# 391/391 [==============================] - 63s 162ms/step - loss: 1.1650 - accuracy: 0.6925 - val_loss: 0.7345 - val_accuracy: 0.7462
# Epoch 15/1000000
# 391/391 [==============================] - 62s 160ms/step - loss: 1.1339 - accuracy: 0.7116 - val_loss: 0.7053 - val_accuracy: 0.7555
# Epoch 16/1000000
# 391/391 [==============================] - 62s 159ms/step - loss: 1.1218 - accuracy: 0.7218 - val_loss: 0.6806 - val_accuracy: 0.7647
# Epoch 17/1000000
# 391/391 [==============================] - 62s 160ms/step - loss: 1.1239 - accuracy: 0.7258 - val_loss: 0.7349 - val_accuracy: 0.7483
# Epoch 18/1000000
# 391/391 [==============================] - 62s 159ms/step - loss: 1.1093 - accuracy: 0.7372 - val_loss: 0.6995 - val_accuracy: 0.7613
# Epoch 19/1000000
# 391/391 [==============================] - 62s 159ms/step - loss: 1.0887 - accuracy: 0.7447 - val_loss: 0.7687 - val_accuracy: 0.7447
# Epoch 20/1000000
# 391/391 [==============================] - 62s 159ms/step - loss: 1.0798 - accuracy: 0.7525 - val_loss: 0.8214 - val_accuracy: 0.7312
# Epoch 21/1000000
# 391/391 [==============================] - 62s 159ms/step - loss: 1.0769 - accuracy: 0.7534 - val_loss: 0.6194 - val_accuracy: 0.7903
# Epoch 22/1000000
# 391/391 [==============================] - 62s 159ms/step - loss: 1.0682 - accuracy: 0.7601 - val_loss: 0.6394 - val_accuracy: 0.7853
# Epoch 23/1000000
# 391/391 [==============================] - 62s 159ms/step - loss: 1.0696 - accuracy: 0.7615 - val_loss: 0.6368 - val_accuracy: 0.7818
# Epoch 24/1000000
# 391/391 [==============================] - 62s 159ms/step - loss: 1.0521 - accuracy: 0.7704 - val_loss: 0.5874 - val_accuracy: 0.7988
# Epoch 25/1000000
# 391/391 [==============================] - 64s 163ms/step - loss: 1.0548 - accuracy: 0.7671 - val_loss: 0.6864 - val_accuracy: 0.7668
# Epoch 26/1000000
# 391/391 [==============================] - 64s 163ms/step - loss: 1.0454 - accuracy: 0.7739 - val_loss: 0.6711 - val_accuracy: 0.7679
# Epoch 27/1000000
# 391/391 [==============================] - 63s 162ms/step - loss: 1.0458 - accuracy: 0.7722 - val_loss: 0.6499 - val_accuracy: 0.7761
# Epoch 28/1000000
# 391/391 [==============================] - 63s 162ms/step - loss: 1.0470 - accuracy: 0.7753 - val_loss: 0.6929 - val_accuracy: 0.7767
# Epoch 29/1000000
# 391/391 [==============================] - 64s 163ms/step - loss: 0.9646 - accuracy: 0.8002 - val_loss: 0.4637 - val_accuracy: 0.8423
# Epoch 30/1000000
# 391/391 [==============================] - 63s 162ms/step - loss: 0.7595 - accuracy: 0.8588 - val_loss: 0.4273 - val_accuracy: 0.8541
# Epoch 31/1000000
# 391/391 [==============================] - 63s 162ms/step - loss: 0.7088 - accuracy: 0.8636 - val_loss: 0.4178 - val_accuracy: 0.8577
# Epoch 32/1000000
# 391/391 [==============================] - 64s 163ms/step - loss: 0.6775 - accuracy: 0.8667 - val_loss: 0.4317 - val_accuracy: 0.8575
# Epoch 33/1000000
# 391/391 [==============================] - 63s 162ms/step - loss: 0.6480 - accuracy: 0.8682 - val_loss: 0.4463 - val_accuracy: 0.8530
# Epoch 34/1000000
# 391/391 [==============================] - 64s 163ms/step - loss: 0.6329 - accuracy: 0.8686 - val_loss: 0.4390 - val_accuracy: 0.8540
# Epoch 35/1000000
# 391/391 [==============================] - 63s 162ms/step - loss: 0.6216 - accuracy: 0.8694 - val_loss: 0.4182 - val_accuracy: 0.8589
# Epoch 36/1000000
# 391/391 [==============================] - 63s 162ms/step - loss: 0.6219 - accuracy: 0.8666 - val_loss: 0.4245 - val_accuracy: 0.8606
# Epoch 37/1000000
# 391/391 [==============================] - 64s 163ms/step - loss: 0.6137 - accuracy: 0.8687 - val_loss: 0.4569 - val_accuracy: 0.8433
# Epoch 38/1000000
# 391/391 [==============================] - 64s 163ms/step - loss: 0.6071 - accuracy: 0.8719 - val_loss: 0.4681 - val_accuracy: 0.8498
# Epoch 39/1000000
# 391/391 [==============================] - 63s 162ms/step - loss: 0.6038 - accuracy: 0.8715 - val_loss: 0.4141 - val_accuracy: 0.8587
# Epoch 40/1000000
# 391/391 [==============================] - 64s 163ms/step - loss: 0.6033 - accuracy: 0.8734 - val_loss: 0.4081 - val_accuracy: 0.8623
# Epoch 41/1000000
# 391/391 [==============================] - 63s 162ms/step - loss: 0.6004 - accuracy: 0.8732 - val_loss: 0.4251 - val_accuracy: 0.8566
# Epoch 42/1000000
# 391/391 [==============================] - 64s 165ms/step - loss: 0.6017 - accuracy: 0.8727 - val_loss: 0.4395 - val_accuracy: 0.8527
# Epoch 43/1000000
# 391/391 [==============================] - 64s 165ms/step - loss: 0.5973 - accuracy: 0.8730 - val_loss: 0.3893 - val_accuracy: 0.8673
# Epoch 44/1000000
# 391/391 [==============================] - 64s 163ms/step - loss: 0.6060 - accuracy: 0.8720 - val_loss: 0.4108 - val_accuracy: 0.8632
# Epoch 45/1000000
# 391/391 [==============================] - 64s 164ms/step - loss: 0.5976 - accuracy: 0.8759 - val_loss: 0.4465 - val_accuracy: 0.8443
# Epoch 46/1000000
# 391/391 [==============================] - 73s 188ms/step - loss: 0.5595 - accuracy: 0.7793 - val_loss: 0.3309 - val_accuracy: 0.8865
# Epoch 47/1000000
# 391/391 [==============================] - 99s 253ms/step - loss: 0.4520 - accuracy: 0.5256 - val_loss: 0.3249 - val_accuracy: 0.8923
# Epoch 48/1000000
# 391/391 [==============================] - 98s 250ms/step - loss: 0.4280 - accuracy: 0.5312 - val_loss: 0.3069 - val_accuracy: 0.9017
# Epoch 49/1000000
# 391/391 [==============================] - 98s 250ms/step - loss: 0.4114 - accuracy: 0.5420 - val_loss: 0.3171 - val_accuracy: 0.8948
# Epoch 50/1000000
# 391/391 [==============================] - 97s 249ms/step - loss: 0.3974 - accuracy: 0.5429 - val_loss: 0.3053 - val_accuracy: 0.9037
# Epoch 51/1000000
# 391/391 [==============================] - 99s 252ms/step - loss: 0.3841 - accuracy: 0.5509 - val_loss: 0.3082 - val_accuracy: 0.8998
# Epoch 52/1000000
# 391/391 [==============================] - 98s 250ms/step - loss: 0.3718 - accuracy: 0.5548 - val_loss: 0.3134 - val_accuracy: 0.9010
# Epoch 53/1000000
# 370/391 [===========================>..] - ETA: 5s - loss: 0.3677 - accuracy: 0.5545 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00

# %%
# Test the model
x_test, y_test = ds_super_res.test_data[:]
eval_model(model, x_test, y_test)
# Out:
# 10000/10000 [==============================] - 3s 313us/step
# Test loss: 0.5213694954872131
# Test accuracy: 0.8955

# %%
# Save model, plots and history
save(model, history, 'res-net-28-2-1hr-dropout-IS-superRes8x8', True)

# %%
# Load model and draw plots 
path = "gdrive/My Drive/"
file_name = "res-net-28-2-1hr-dropout-IS-superRes8x8"
model = load_model(path + file_name + ".h5", custom_objects = {'LayerNormalization' : LayerNormalization})

# Display Saved plots
listOfImageNames = [path + file_name + "-acc.png",
                    path + file_name + "-loss.png"]

for imageName in listOfImageNames:
    display(Image(filename=imageName))
    
# Load history
history = np.load(path + file_name + "-history.npy")

# %% [markdown]
# ### Wide ResNet (28-2) with dropout and without IS for max time of 1 hr on the output of ESRGAN (8x8 -> 32x32)

# %%
args = Args(depth = 28, width = 2, presample = 3.0, batch_size = 128, time_budget = 1, dropout = 0.3, useIS = False)
model, history = build_wide_res(args, ds_super_res)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 16)   432         input_1[0][0]
# __________________________________________________________________________________________________
# layer_normalization_1 (LayerNor (None, 32, 32, 16)   17          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 16)   0           layer_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 32)   4608        activation_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 32, 32, 32)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# layer_normalization_2 (LayerNor (None, 32, 32, 32)   33          dropout_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 32)   0           layer_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 32)   512         conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 32)   9216        activation_2[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 32)   0           conv2d_4[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# layer_normalization_3 (LayerNor (None, 32, 32, 32)   33          add_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 32)   0           layer_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 32)   9216        activation_3[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 32, 32, 32)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# layer_normalization_4 (LayerNor (None, 32, 32, 32)   33          dropout_2[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 32)   0           layer_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 32)   9216        activation_4[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 32, 32, 32)   0           add_1[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# layer_normalization_5 (LayerNor (None, 32, 32, 32)   33          add_2[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 32)   0           layer_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 32)   9216        activation_5[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 32, 32, 32)   0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# layer_normalization_6 (LayerNor (None, 32, 32, 32)   33          dropout_3[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 32)   0           layer_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 32)   9216        activation_6[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 32, 32, 32)   0           add_2[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# layer_normalization_7 (LayerNor (None, 32, 32, 32)   33          add_3[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 32, 32, 32)   0           layer_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 32)   9216        activation_7[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 32, 32, 32)   0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# layer_normalization_8 (LayerNor (None, 32, 32, 32)   33          dropout_4[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 32, 32, 32)   0           layer_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 32)   9216        activation_8[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 32, 32, 32)   0           add_3[0][0]
#                                                                  conv2d_10[0][0]
# __________________________________________________________________________________________________
# layer_normalization_9 (LayerNor (None, 32, 32, 32)   33          add_4[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 32, 32, 32)   0           layer_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 64)   18432       activation_9[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 16, 16, 64)   0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# layer_normalization_10 (LayerNo (None, 16, 16, 64)   65          dropout_5[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 16, 16, 64)   0           layer_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 64)   2048        add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 64)   36864       activation_10[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 16, 16, 64)   0           conv2d_13[0][0]
#                                                                  conv2d_12[0][0]
# __________________________________________________________________________________________________
# layer_normalization_11 (LayerNo (None, 16, 16, 64)   65          add_5[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 16, 16, 64)   0           layer_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 16, 16, 64)   36864       activation_11[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 16, 16, 64)   0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# layer_normalization_12 (LayerNo (None, 16, 16, 64)   65          dropout_6[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 16, 16, 64)   0           layer_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 16, 16, 64)   36864       activation_12[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 16, 16, 64)   0           add_5[0][0]
#                                                                  conv2d_15[0][0]
# __________________________________________________________________________________________________
# layer_normalization_13 (LayerNo (None, 16, 16, 64)   65          add_6[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 16, 16, 64)   0           layer_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 16, 16, 64)   36864       activation_13[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 16, 16, 64)   0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# layer_normalization_14 (LayerNo (None, 16, 16, 64)   65          dropout_7[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 16, 16, 64)   0           layer_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 16, 16, 64)   36864       activation_14[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 16, 16, 64)   0           add_6[0][0]
#                                                                  conv2d_17[0][0]
# __________________________________________________________________________________________________
# layer_normalization_15 (LayerNo (None, 16, 16, 64)   65          add_7[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 16, 16, 64)   0           layer_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 16, 16, 64)   36864       activation_15[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 16, 16, 64)   0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# layer_normalization_16 (LayerNo (None, 16, 16, 64)   65          dropout_8[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 16, 16, 64)   0           layer_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 16, 16, 64)   36864       activation_16[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 16, 16, 64)   0           add_7[0][0]
#                                                                  conv2d_19[0][0]
# __________________________________________________________________________________________________
# layer_normalization_17 (LayerNo (None, 16, 16, 64)   65          add_8[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 16, 16, 64)   0           layer_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 8, 8, 128)    73728       activation_17[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 8, 8, 128)    0           conv2d_20[0][0]
# __________________________________________________________________________________________________
# layer_normalization_18 (LayerNo (None, 8, 8, 128)    129         dropout_9[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 8, 8, 128)    0           layer_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 8, 8, 128)    8192        add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 8, 8, 128)    147456      activation_18[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 8, 8, 128)    0           conv2d_22[0][0]
#                                                                  conv2d_21[0][0]
# __________________________________________________________________________________________________
# layer_normalization_19 (LayerNo (None, 8, 8, 128)    129         add_9[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 8, 8, 128)    0           layer_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 8, 8, 128)    147456      activation_19[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 8, 8, 128)    0           conv2d_23[0][0]
# __________________________________________________________________________________________________
# layer_normalization_20 (LayerNo (None, 8, 8, 128)    129         dropout_10[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 8, 8, 128)    0           layer_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 8, 8, 128)    147456      activation_20[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 8, 8, 128)    0           add_9[0][0]
#                                                                  conv2d_24[0][0]
# __________________________________________________________________________________________________
# layer_normalization_21 (LayerNo (None, 8, 8, 128)    129         add_10[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 8, 8, 128)    0           layer_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 8, 8, 128)    147456      activation_21[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 8, 8, 128)    0           conv2d_25[0][0]
# __________________________________________________________________________________________________
# layer_normalization_22 (LayerNo (None, 8, 8, 128)    129         dropout_11[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 8, 8, 128)    0           layer_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 8, 8, 128)    147456      activation_22[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 8, 8, 128)    0           add_10[0][0]
#                                                                  conv2d_26[0][0]
# __________________________________________________________________________________________________
# layer_normalization_23 (LayerNo (None, 8, 8, 128)    129         add_11[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 8, 8, 128)    0           layer_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 8, 8, 128)    147456      activation_23[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 8, 8, 128)    0           conv2d_27[0][0]
# __________________________________________________________________________________________________
# layer_normalization_24 (LayerNo (None, 8, 8, 128)    129         dropout_12[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 8, 8, 128)    0           layer_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 8, 8, 128)    147456      activation_24[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 8, 8, 128)    0           add_11[0][0]
#                                                                  conv2d_28[0][0]
# __________________________________________________________________________________________________
# layer_normalization_25 (LayerNo (None, 8, 8, 128)    129         add_12[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 8, 8, 128)    0           layer_normalization_25[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 128)          0           activation_25[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 10)           1290        global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 10)           0           dense_1[0][0]
# ==================================================================================================
# Total params: 1,465,827
# Trainable params: 1,465,827
# Non-trainable params: 0
# __________________________________________________________________________________________________
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/1000000
# 391/391 [==============================] - 135s 346ms/step - loss: 2.9125 - acc: 0.1146 - val_loss: 2.6372 - val_acc: 0.1638
# Epoch 2/1000000
# 391/391 [==============================] - 128s 328ms/step - loss: 2.2414 - acc: 0.2527 - val_loss: 1.9848 - val_acc: 0.3374
# Epoch 3/1000000
# 391/391 [==============================] - 129s 329ms/step - loss: 1.8396 - acc: 0.3769 - val_loss: 1.7843 - val_acc: 0.3964
# Epoch 4/1000000
# 391/391 [==============================] - 129s 329ms/step - loss: 1.6375 - acc: 0.4524 - val_loss: 1.7265 - val_acc: 0.3978
# Epoch 5/1000000
# 391/391 [==============================] - 129s 330ms/step - loss: 1.5159 - acc: 0.5092 - val_loss: 1.4858 - val_acc: 0.5343
# Epoch 6/1000000
# 391/391 [==============================] - 129s 329ms/step - loss: 1.4535 - acc: 0.5419 - val_loss: 1.3813 - val_acc: 0.5629
# Epoch 7/1000000
# 391/391 [==============================] - 129s 330ms/step - loss: 1.3609 - acc: 0.5840 - val_loss: 1.5369 - val_acc: 0.5403
# Epoch 8/1000000
# 391/391 [==============================] - 129s 330ms/step - loss: 1.3145 - acc: 0.6088 - val_loss: 1.2428 - val_acc: 0.6320
# Epoch 9/1000000
# 391/391 [==============================] - 128s 329ms/step - loss: 1.2587 - acc: 0.6315 - val_loss: 1.5586 - val_acc: 0.5578
# Epoch 10/1000000
# 391/391 [==============================] - 129s 329ms/step - loss: 1.2555 - acc: 0.6401 - val_loss: 1.1698 - val_acc: 0.6667
# Epoch 11/1000000
# 391/391 [==============================] - 128s 328ms/step - loss: 1.2244 - acc: 0.6529 - val_loss: 1.2071 - val_acc: 0.6595
# Epoch 12/1000000
# 391/391 [==============================] - 128s 328ms/step - loss: 1.2211 - acc: 0.6586 - val_loss: 1.3187 - val_acc: 0.6237
# Epoch 13/1000000
# 391/391 [==============================] - 129s 329ms/step - loss: 1.1919 - acc: 0.6734 - val_loss: 1.2146 - val_acc: 0.6650
# Epoch 14/1000000
# 391/391 [==============================] - 129s 329ms/step - loss: 1.1842 - acc: 0.6849 - val_loss: 1.2350 - val_acc: 0.6742
# Epoch 15/1000000
# 391/391 [==============================] - 129s 329ms/step - loss: 0.9384 - acc: 0.7675 - val_loss: 0.9367 - val_acc: 0.7661
# Epoch 16/1000000
# 391/391 [==============================] - 128s 328ms/step - loss: 0.8724 - acc: 0.7806 - val_loss: 0.8840 - val_acc: 0.7757
# Epoch 17/1000000
# 391/391 [==============================] - 128s 328ms/step - loss: 0.8363 - acc: 0.7896 - val_loss: 0.8496 - val_acc: 0.7874
# Epoch 18/1000000
# 391/391 [==============================] - 128s 327ms/step - loss: 0.8172 - acc: 0.7896 - val_loss: 0.8325 - val_acc: 0.7852
# Epoch 19/1000000
# 391/391 [==============================] - 128s 328ms/step - loss: 0.7956 - acc: 0.7959 - val_loss: 0.9008 - val_acc: 0.7630
# Epoch 20/1000000
# 391/391 [==============================] - 128s 328ms/step - loss: 0.7699 - acc: 0.8032 - val_loss: 0.7962 - val_acc: 0.8020
# Epoch 21/1000000
# 391/391 [==============================] - 129s 329ms/step - loss: 0.7531 - acc: 0.8087 - val_loss: 0.7865 - val_acc: 0.7960
# Epoch 22/1000000
# 391/391 [==============================] - 129s 330ms/step - loss: 0.7493 - acc: 0.8098 - val_loss: 0.8243 - val_acc: 0.7836
# Epoch 23/1000000
# 391/391 [==============================] - 129s 330ms/step - loss: 0.6799 - acc: 0.8310 - val_loss: 0.6466 - val_acc: 0.8468
# Epoch 24/1000000
# 391/391 [==============================] - 129s 330ms/step - loss: 0.5957 - acc: 0.8613 - val_loss: 0.6554 - val_acc: 0.8421
# Epoch 25/1000000
# 391/391 [==============================] - 129s 329ms/step - loss: 0.5730 - acc: 0.8670 - val_loss: 0.6935 - val_acc: 0.8349
# Epoch 26/1000000
# 391/391 [==============================] - 129s 330ms/step - loss: 0.5575 - acc: 0.8712 - val_loss: 0.6461 - val_acc: 0.8486
# Epoch 27/1000000
# 391/391 [==============================] - 129s 330ms/step - loss: 0.5497 - acc: 0.8730 - val_loss: 0.6445 - val_acc: 0.8435
# Epoch 28/1000000
# 373/391 [===========================>..] - ETA: 5s - loss: 0.5394 - acc: 0.8755

# %%
# Test the model
x_test, y_test = ds_super_res.test_data[:]
eval_model(model, x_test, y_test)
# Out:
# 10000/10000 [==============================] - 8s 841us/step
# Test loss: 0.6631258937835693
# Test accuracy: 0.8385

# %%
# Save model, plots and history
save(model, history, 'res-net-28-2-1hr-dropout-noIS-superRes8x8', False)

# %%
# Load model and draw plots 
path = "gdrive/My Drive/"
file_name = "res-net-28-2-1hr-dropout-noIS-superRes8x8"
model = load_model(path + file_name + ".h5", custom_objects = {'LayerNormalization' : LayerNormalization})

# Display Saved plots
listOfImageNames = [path + file_name + "-acc.png",
                    path + file_name + "-loss.png"]

for imageName in listOfImageNames:
    display(Image(filename=imageName))
    
# Load history
history = np.load(path + file_name + "-history.npy")

# %% [markdown]
# # Evaluation Plots

# %%
path = "gdrive/My Drive/"
file_name = "res-net-28-2-1hr-dropout-IS"
h1 = np.load(path + file_name + "-history.npy")

file_name = "res-net-28-2-1hr-dropout-noIS"
h2 = np.load(path + file_name + "-history.npy")

file_name = "res-net-28-2-1hr-nodropout-IS"
h3 = np.load(path + file_name + "-history.npy")

file_name = "res-net-28-2-1hr-nodropout-noIS"
h4 = np.load(path + file_name + "-history.npy")

file_name = "res-net-28-2-1hr-dropout-IS-superRes8x8"
h5 = np.load(path + file_name + "-history.npy")

# Generate epoch array
epochs = []
for i in range(min(h1.shape[1], h2.shape[1], h3.shape[1], h4.shape[1], h5.shape[1])):
  epochs.append(i)
epochs = np.array(epochs)

# %%
# Comparison of test loss (note: here test loss is the validation loss as the val set passed to Keras is the test set)            
row = 3 # For test loss
plt.plot(epochs, h1[row, :epochs[-1] + 1])
plt.plot(epochs, h2[row, :epochs[-1] + 1])
plt.plot(epochs, h3[row, :epochs[-1] + 1])
plt.plot(epochs, h4[row, :epochs[-1] + 1])
plt.xlabel('epochs')
plt.ylabel('loss')
plt.title('Test Loss')
plt.legend(['Drop, IS', 'Drop, noIS', 'noDrop, IS', 'noDrop, noIS'])
plt.savefig('test_loss.png')
plt.show()

files.download('test_loss.png')

# %%
# Comparison of test accuracy
row = 1 # For test acc
plt.plot(epochs, h1[row, :epochs[-1] + 1])
plt.plot(epochs, h2[row, :epochs[-1] + 1])
plt.plot(epochs, h3[row, :epochs[-1] + 1])
plt.plot(epochs, h4[row, :epochs[-1] + 1])
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.title('Test Accuracy')
plt.legend(['Drop, IS', 'Drop, noIS', 'noDrop, IS', 'noDrop, noIS'])
plt.savefig('test_acc.png')
plt.show()

files.download('test_acc.png')

# %%
# Comparison of train loss
row = 2 # For train loss
plt.plot(epochs, h1[row, :epochs[-1] + 1])
plt.plot(epochs, h2[row, :epochs[-1] + 1])
plt.plot(epochs, h3[row, :epochs[-1] + 1])
plt.plot(epochs, h4[row, :epochs[-1] + 1])
plt.xlabel('epochs')
plt.ylabel('loss')
plt.title('Training Loss')
plt.legend(['Drop, IS', 'Drop, noIS', 'noDrop, IS', 'noDrop, noIS'])
plt.savefig('train_loss.png')
plt.show()

files.download('train_loss.png')

# %%
# Comparison with upsampled CIFAR10 (with dropout and with IS)
row = 1 # test acc
plt.plot(epochs, h1[row, :epochs[-1] + 1])
plt.plot(epochs, h5[row, :epochs[-1] + 1])
plt.legend(['Original', 'Upsampled'])
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.title('Test Accuracy')
plt.savefig('test_acc_upsamp.png')
plt.show()

files.download('test_acc_upsamp.png')
